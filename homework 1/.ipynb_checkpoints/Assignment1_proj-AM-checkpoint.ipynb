# %% [markdown]
# # Deep Learning Course

# %% [markdown]
# ## Assignment 1

# %% [markdown]
# #### Assignment Goals:
#
# * Start with Keras.
# * Implement and apply logistic regression and multi-layer feed-forward neural network classifiers.
# * Understand the differences and trade-offs between linear regression, logistic regression, and multi-layer feed-forward neural network.
#
# In this assignment, you will be asked to install Keras and Jupyter Notebook. Keras is packaged with TensorFlow 2.0 as tensorflow.keras, so you actually need to install Tensorflow 2.0. (TA's environment to run your code is Python 3.7 + Tensorflow 2.4). In addition, you are required to design several models to classify a Toy Dataset (Figure 1).
#
# #### Dataset:
#
# We provide a toy dataset, which has 200 instances and 2 features. See below "Toy Data and Helper Functions" section for toy data generation code.
#
# You do not need to generate separated training dataset and test dataset for this assignment. Both training and prediction will both be on one dataset. Directly use the "sample, target" variables we provide as the dataset for your assignment.
#
# In the following accuracy is defined as the empirical accuracy on the training set, that is, accuracy = {number of correctly predicted instances}/{number of all instances in dataset}).
#
# #### Requirements
#
# 1. Install Keras (Tensorflow 2) and Jupyter Notebook. (10 points)
#
# 2. Implement a [logistic regression](https://towardsdatascience.com/logistic-regression-detailed-overview-46c4da4303bc) to classify the Toy Dataset. (20 points) We have provided a very simple linear regression example, please refer to the example and implement your logistic regression model.
#     * You should determine: what loss function and what optimization algorithm do you plan to use? (4 points)
#     * Try to reach > 72% accuracy. (4 points)
#     * We have provided a visualize() helper function, you can visualize the model's decision boundary using that function. What's more, you are asked to compute and visualize **the equation of the decision boundary** of your trained **logistic regression**. Fill in the 'equation of decision boundary' column in the following table. Then you can modify the visualize() function or implement a new visualization function to draw the linear decision boundary (Hint: should be a straight line aligned with the decision boundary plotted in visualize()). (5 points)
#
#
# 3. Implement a multi-layer linear neural network (>= 2 hidden layers) to classify the Toy Dataset. (20 points) A deep linear neural network is a deep feed-forward neural network without activation functions (See [here](https://www.cs.princeton.edu/courses/archive/fall19/cos597B/lecnotes/linearnetsbyNC.pdf), page 11-13 for detail introduction of linear neural networks).
#     * You should determine: what loss function and what optimization algorithm do you plan to use, what is your network structure? (4 points)
#     * Try to reach > 72% accuracy. (4 points)
#     * Compute and visualize **the equation of the decision boundary** of your trained **linear neural network**. Fill in the 'equation of decision boundary' column in the following table. Then you can modify the visualize() function or implement a new visualization function to draw the linear decision boundary. (5 points)
#
#
# 4. Implement a multi-layer feed-forward neural network (>= 2 hidden layers). (20 points)
#     * You should determine: what loss function and what optimization algorithm do you plan to use? what is your network structure? what activation function do you use? (5 points)
#     * Try to reach 100% accuracy. (5 points)
#
#
# 5. Add L2-regularization to your implemented nonlinear neural network in (4.). Set the coefficient of L2-regularization to be 0.01, 2, 100, respectively. How do different values of coefficient of L2-regularization affect the model (i.e., model parameters, loss value, accuracy, decision boundary)? You can use a table to compare models trained without regularization, with different coefficients of regularization. (20 points)
#     * Please draw your table and analysis in the '**Answers and Analysis**' section.
#
#
# You should:
#
# * Train each of your models to its best accuracy. Then fill in the following table in the '**Answers and Analysis**' section.
#
# * Complete the '**Answers and Analysis**' section.
#
# #### Answers and Analysis
#
# * First, fill in the following table. The '-' indicates a cell that does not need to be filled in.
#
# |  Model | Loss  | Accuracy | Equation of Decision Boundary | NN Structure | Activation Function | Loss Function |
# |---|:---:|:---:|:---: | :---: | :---: | :---: |
# | Linear Regression  |  0.14 |  72.96% | $-1.28x_1+7.62x_2 - 0.07=0$  | -  | -  | Mean Square Error  |
# | Logistic Regression  |   |   |   | -  |  - |   |
# | Linear Neural Network  |   |   |   |   |   |   |
# | Feedforward Neural Network |   |   | -  |   |   |   |
#
#
# * Then, compare and analyze the classification results of your models. In particular, are there any differences between the performance (i.e., accuracy, loss value) of linear regression, logistic regression, linear neural network and deep nonlinear neural network? What do you think is the reason for the difference? (10 points)
#
# * Your table and analysis of (5. Add L2-regularization) here.
#
#
#
# #### Submission Notes:
#
# Please use Jupyter Notebook. The notebook should include the final code, results and your answers. You should submit your Notebook in both .pdf and .ipynb format.
#
#
#
# #### Instructions:
#
# The university policy on academic dishonesty and plagiarism (cheating) will be taken very seriously in this course. Everything submitted should be your own writing or coding. You must not let other students copy your work. Spelling and grammar count.
#
#
# Your assignments will be marked based on correctness, originality (the implementations and ideas are from yourself), clarity and performance.
# Clarity means whether the logic of your code is easy to follow. This includes 1) comments to explain the logic of your code 2) meaningful variable names. Performance includes loss value and accuracy after training.

# %% [markdown]
# ## Your Implementation

# %% [markdown]
# ### Toy Data and Helper Functions

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt

# %%
# helper functions

# helper function for geterating the data
def data_generator(N = 200,D = 2,K = 2):
    """
    N: number of points per class; 
    D: dimensionality; 
    K: number of classes
    """
    np.random.seed(0)
    X = np.zeros((N*K,D))
    y = np.zeros((N*K), dtype='uint8')
    
    for j in range(K):
      ix = range(N*j,N*(j+1))
      r = np.linspace(0.0,1,N) # radius
      t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.3 # theta
      X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
      y[ix] = j
    
    fig = plt.figure()
    plt.title('Figure 1: DataSet')
    plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)
   
    plt.xlim(X.min()-.5, X.max()+.5)
    plt.ylim(X.min()-.5, X.max()+.5)
    
    return X,y


# helper function for visualizing the decision boundaries
def visualize(sample, target, model):
    """
    function for visualizing the classifier boundaries on the TOY dataset.

    sample: Training data features
    target: Target 
    model: the model
    """
    h = 0.02
    x_min, x_max = sample[:, 0].min() - 1, sample[:, 0].max() + 1
    y_min, y_max = sample[:, 1].min() - 1, sample[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    

    Z = model.predict_classes(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    
    fig = plt.figure()
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
    plt.scatter(sample[:, 0], sample[:, 1], c=target, s=40, cmap=plt.cm.Spectral)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    
    return

def visualize_mod(sample, target, model):
    """
    function for visualizing the classifier boundaries on the TOY dataset.

    sample: Training data features
    target: Target 
    model: the model
    """
    h = 0.02
    x_min, x_max = sample[:, 0].min() - 1, sample[:, 0].max() + 1
    y_min, y_max = sample[:, 1].min() - 1, sample[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    
    w1 = model.get_weights()[0][0]
    w2 = model.get_weights()[0][1]
    b = model.get_weights()[1]
    
    x1 = np.arange(x_min,x_max,h)
    x2 = -(w1/w2)*x1 -b/w2
    
    Z = model.predict_classes(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    print(w1[0],"x1 + ",w2[0],"x2",b[0],"= 0")
    fig = plt.figure()
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
    plt.scatter(sample[:, 0], sample[:, 1], c=target, s=40, cmap=plt.cm.Spectral)
    plt.scatter(x1,x2,c='green', s=2)
    
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    
    return


def visualize_dlnn(sample, target, model):
    """
    function for visualizing the classifier boundaries on the TOY dataset.

    sample: Training data features
    target: Target 
    model: the model
    """
    h = 0.02
    x_min, x_max = sample[:, 0].min() - 1, sample[:, 0].max() + 1
    y_min, y_max = sample[:, 1].min() - 1, sample[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    
    wts = model.get_weights()
    I = np.ones(shape= (2,2))
    B = np.zeros(shape=(1,2))
    #print(wts)
    index = 0
    count = 1
    for i in range(3):
        I = np.multiply(I,wts[i+index])

        B = np.multiply(B, wts[i+index])
        #print(I, B)
        B = np.sum(B,axis = 0)
        B = B + wts[i+count]
        index+=2
        count+=1
    
    x1 = np.arange(x_min,x_max,h)
    
    II = np.sum(I,axis = 0).reshape(2,1)
    w1 = II[0][0]
    w2 = II[1][0]
    b = np.sum(B)
    ww1 = w1*wts[-2][0]
    ww2 = w2*wts[-2][1]
    bb = b+wts[-1]
    
    x2 = -(ww1*x1)/ww2 -b/(ww2)
    
    Z = model.predict_classes(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    #print(ww1,"x1",ww2,"x2",bb,"= 0")
    fig = plt.figure()
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
    plt.scatter(sample[:, 0], sample[:, 1], c=target, s=40, cmap=plt.cm.Spectral)
    plt.scatter(x1,x2,c='green', s=50)
    
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    
    return


def visualize_dlnn2(sample, target, model):
    """
    function for visualizing the classifier boundaries on the TOY dataset.

    sample: Training data features
    target: Target 
    model: the model
    """
    h = 0.02
    x_min, x_max = sample[:, 0].min() - 1, sample[:, 0].max() + 1
    y_min, y_max = sample[:, 1].min() - 1, sample[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    wts = DLNN_model.get_weights()
    #print(wts)
    index = 0
    count = 1
    I = np.ones(shape = (2, 1))
    BB = 1
    for i in range(3):
        W = np.sum(wts[i+index],axis = 1).reshape(2,1)
        I = [W[0]*I[0], W[1]*I[1]]
        B = [BB*W[0], BB*W[1]]
        BB = B[0] + wts[i+count][0] + B[1]+wts[i+count][1]
        index += 1
        count += 1

    w1 = I[0]*wts[-2][0]
    w2 = I[1]*wts[-2][1]
    b = BB + wts[-1][0]
    
    x1 = np.arange(x_min,x_max,h)
    x2 = -(w1*x1)/w2 - b/(w2)
    
    Z = model.predict_classes(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    print(w1,"x1",w2,"x2",b,"= 0")
    fig = plt.figure()
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
    plt.scatter(sample[:, 0], sample[:, 1], c=target, s=40, cmap=plt.cm.Spectral)
    plt.scatter(x1,x2,c='green', s=50)
    
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    
    return

# %%
#  TOY DataSet
sample, target = data_generator(N = 200)
# print(target.shape)

# %% [markdown]
# ### Given Example: Linear Regression
#
#
# Note that linear regression is usually used for regression tasks, not classification tasks. However, it can be used for binary classification problems (be labeled 0, 1) with a threshold classifier. That is, when linear regression outputs > 0.5, the prediction is 1; otherwise, the prediction is 0.

# %%
#Define the model
linear_regression = keras.Sequential()

linear_regression.add(keras.layers.Dense(1,"linear"))

linear_regression.compile(optimizer="sgd",loss= keras.losses.MeanSquaredError(), metrics=['accuracy'])

# Train the model
value_epoches = linear_regression.fit(sample, target, epochs=5,batch_size=1)
# Out:
# Train on 400 samples
# Epoch 1/5
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.3960 - accuracy: 0.4950
# Epoch 2/5
# 400/400 [==============================] - 0s 957us/sample - loss: 0.1537 - accuracy: 0.7600
# Epoch 3/5
# 400/400 [==============================] - 0s 1ms/sample - loss: 0.1455 - accuracy: 0.7325
# Epoch 4/5
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.1442 - accuracy: 0.7300
# Epoch 5/5
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.1438 - accuracy: 0.7450

# %%
visualize(sample,target, linear_regression)

# %% [markdown]
# **Here is an example: the green line is the line of the decision boundary. You should draw the linear decision boundary like this.**

# %% [markdown]
# ![hw1_img1.png](hw1_img1.png)

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# #### Logistic Regression Model & Training Accuracy

# %%
# implement your logistic regression here
logistic_regression = keras.Sequential()

logistic_regression.add(keras.layers.Dense(1,input_shape=(2,),
                                          activation = keras.activations.sigmoid,
                                          bias_initializer=keras.initializers.Constant(0.1)))

logistic_regression.compile(optimizer="sgd",loss= 'binary_crossentropy', metrics=['binary_accuracy'])

# Train the model
value_epoches = logistic_regression.fit(sample, target, epochs=10,batch_size=1,
                                        shuffle=True, verbose = 1, validation_split=0.2)
# Out:
# Train on 320 samples, validate on 80 samples
# Epoch 1/10
# 320/320 [==============================] - 1s 2ms/sample - loss: 0.5463 - binary_accuracy: 0.8562 - val_loss: 0.8827 - val_binary_accuracy: 0.3625
# Epoch 2/10
# 320/320 [==============================] - 1s 2ms/sample - loss: 0.5087 - binary_accuracy: 0.8406 - val_loss: 0.9464 - val_binary_accuracy: 0.3250
# Epoch 3/10
# 320/320 [==============================] - 0s 2ms/sample - loss: 0.4865 - binary_accuracy: 0.8281 - val_loss: 0.9797 - val_binary_accuracy: 0.3625
# Epoch 4/10
# 320/320 [==============================] - 1s 3ms/sample - loss: 0.4692 - binary_accuracy: 0.8375 - val_loss: 1.0038 - val_binary_accuracy: 0.3875
# Epoch 5/10
# 320/320 [==============================] - 1s 2ms/sample - loss: 0.4548 - binary_accuracy: 0.8375 - val_loss: 1.0235 - val_binary_accuracy: 0.3875
# Epoch 6/10
# 320/320 [==============================] - 1s 3ms/sample - loss: 0.4425 - binary_accuracy: 0.8469 - val_loss: 1.0386 - val_binary_accuracy: 0.3875
# Epoch 7/10
# 320/320 [==============================] - 1s 2ms/sample - loss: 0.4317 - binary_accuracy: 0.8500 - val_loss: 1.0571 - val_binary_accuracy: 0.3875
# Epoch 8/10
# 320/320 [==============================] - 1s 2ms/sample - loss: 0.4223 - binary_accuracy: 0.8531 - val_loss: 1.0647 - val_binary_accuracy: 0.4125
# Epoch 9/10
# 320/320 [==============================] - 0s 1ms/sample - loss: 0.4138 - binary_accuracy: 0.8594 - val_loss: 1.0746 - val_binary_accuracy: 0.4250
# Epoch 10/10
# 320/320 [==============================] - 0s 1ms/sample - loss: 0.4063 - binary_accuracy: 0.8625 - val_loss: 1.0875 - val_binary_accuracy: 0.4375

# %% [markdown]
# #### Logistic Regression Model Visualization

# %%
print(logistic_regression.summary())
tf.keras.utils.plot_model(logistic_regression,show_shapes=True,
                          show_layer_names=True,
                          rankdir="TB",expand_nested=True,dpi=96,)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# #### Visualization: Decision Boundary and Equation

# %%
visualize_mod(sample,target, logistic_regression)
# Out:
# -1.9442466 x1 +  2.5283387 x2 -0.37314713 = 0

# %% [markdown]
# ### Deep Linear Neural Network

# %%
wts = DLNN_model.get_weights()
#print(wts)
index = 0
count = 1
I = np.ones(shape = (2, 1))
B = np.zeros(shape=(2,1))
for i in range(3):
    W = np.sum(wts[i+index],axis = 1).reshape(2,1)
    I = [W[0]*I[0], W[1]*I[1]]
    B = [B[0]*W[0], B[1]*W[1]]
    B = [B[0] + wts[i+count][0], B[1]+wts[i+count][1]]
    index += 1
    count += 1
    
w1 = I[0]*wts[-2][0]
w2 = I[1]*wts[-2][1]
b = B[0]+wts[-1][0]

    
print(w1,w2,b)
# Out:
# [-0.94963478] [-0.34825337] [-0.28999443]

# %% [markdown]
# ####  Deep linear NN Model & Training Accuracy

# %%
# # implement your nonlinear feed forward neural network here
DLNN_model = keras.Sequential()

DLNN_model.add(keras.layers.Dense(2,input_shape=(2,),
                                          activation = tf.keras.activations.linear,))
DLNN_model.add(keras.layers.Dense(2,input_shape=(2,),
                                          activation = tf.keras.activations.linear,))
DLNN_model.add(keras.layers.Dense(2,input_shape=(2,),
                                          activation = tf.keras.activations.linear,))

DLNN_model.add(keras.layers.Dense(1,input_shape=(2,),
                                          activation = tf.keras.activations.sigmoid,))

DLNN_model.compile(optimizer="sgd",loss= 'binary_crossentropy', metrics=['binary_accuracy'])

# Train the model
value_epoches = DLNN_model.fit(sample, target, epochs=5,batch_size=1,
                                        shuffle=True, verbose = 1, validation_split=0.2)
# Out:
# Train on 320 samples, validate on 80 samples
# Epoch 1/5
# 320/320 [==============================] - 1s 2ms/sample - loss: 0.6816 - binary_accuracy: 0.5719 - val_loss: 1.2928 - val_binary_accuracy: 0.0000e+00
# Epoch 2/5
# 320/320 [==============================] - 0s 2ms/sample - loss: 0.5862 - binary_accuracy: 0.6313 - val_loss: 1.1352 - val_binary_accuracy: 0.2000
# Epoch 3/5
# 320/320 [==============================] - 1s 2ms/sample - loss: 0.4165 - binary_accuracy: 0.8531 - val_loss: 1.6202 - val_binary_accuracy: 0.3875
# Epoch 4/5
# 320/320 [==============================] - 1s 2ms/sample - loss: 0.3221 - binary_accuracy: 0.8594 - val_loss: 2.3493 - val_binary_accuracy: 0.3750
# Epoch 5/5
# 320/320 [==============================] - 1s 2ms/sample - loss: 0.3044 - binary_accuracy: 0.8562 - val_loss: 2.4941 - val_binary_accuracy: 0.4125

# %% [markdown]
# #### DLL Model Visualization

# %%
print(DLNN_model.summary())
tf.keras.utils.plot_model(DLNN_model,show_shapes=True,
                          show_layer_names=True,
                          rankdir="TB",expand_nested=True,dpi=96,)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 2)                 6
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 6
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 6
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
visualize_dlnn2(sample,target, DLNN_model)
# Out:
# [-0.94963478] x1 [-0.34825337] x2 [-0.27111903] = 0

# %% [markdown]
# ### Deep Neural Network

# %% [markdown]
# #### Feed forward Deep Neural Network

# %%
# implement your nonlinear feed forward neural network here
DFFNN_model = keras.Sequential()

DFFNN_model.add(keras.layers.Dense(96,input_shape=(2,),
                                          activation = tf.keras.activations.tanh,))
DFFNN_model.add(keras.layers.Dense(200,input_shape=(96,),
                                          activation = tf.keras.activations.tanh,))
DFFNN_model.add(keras.layers.Dense(96,input_shape=(200,),
                                          activation = tf.keras.activations.relu,))
DFFNN_model.add(keras.layers.Dense(24,input_shape=(48,),
                                          activation = tf.keras.activations.relu,))
DFFNN_model.add(keras.layers.Dense(2,input_shape=(24,),
                                          activation = tf.keras.activations.relu,))

DFFNN_model.add(keras.layers.Dense(1,input_shape=(2,),
                                          activation = tf.keras.activations.sigmoid,))

DFFNN_model.compile(optimizer="adam",loss= 'binary_crossentropy', metrics=['accuracy'])

# Train the model
value_epoches = DFFNN_model.fit(sample, target, epochs=200,batch_size=1,
                                        shuffle=True, verbose = 1, validation_split=0.0)
# Out:
# Train on 400 samples
# Epoch 1/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.5767 - accuracy: 0.7600
# Epoch 2/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.2919 - accuracy: 0.8950
# Epoch 3/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.1084 - accuracy: 0.9675
# Epoch 4/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.1631 - accuracy: 0.9400
# Epoch 5/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0846 - accuracy: 0.9775
# Epoch 6/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0515 - accuracy: 0.9775
# Epoch 7/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0298 - accuracy: 0.9825
# Epoch 8/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0445 - accuracy: 0.9825
# Epoch 9/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0382 - accuracy: 0.9850
# Epoch 10/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0909 - accuracy: 0.9750
# Epoch 11/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0808 - accuracy: 0.9775
# Epoch 12/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0743 - accuracy: 0.9725
# Epoch 13/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0347 - accuracy: 0.9900
# Epoch 14/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0255 - accuracy: 0.9925
# Epoch 15/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0359 - accuracy: 0.9825
# Epoch 16/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0251 - accuracy: 0.9875
# Epoch 17/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0316 - accuracy: 0.9900
# Epoch 18/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0169 - accuracy: 0.9900
# Epoch 19/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.1858 - accuracy: 0.9675
# Epoch 20/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0361 - accuracy: 0.9825
# Epoch 21/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0272 - accuracy: 0.9925
# Epoch 22/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0359 - accuracy: 0.9825
# Epoch 23/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0254 - accuracy: 0.9900
# Epoch 24/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0472 - accuracy: 0.9850
# Epoch 25/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0143 - accuracy: 0.9925
# Epoch 26/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0225 - accuracy: 0.9925
# Epoch 27/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0274 - accuracy: 0.9875
# Epoch 28/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0353 - accuracy: 0.9900
# Epoch 29/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.1258 - accuracy: 0.9675
# Epoch 30/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.1267 - accuracy: 0.9725
# Epoch 31/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0149 - accuracy: 0.9925
# Epoch 32/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0212 - accuracy: 0.9900
# Epoch 33/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0075 - accuracy: 0.9975
# Epoch 34/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0122 - accuracy: 0.9950
# Epoch 35/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0305 - accuracy: 0.9850
# Epoch 36/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0194 - accuracy: 0.9925
# Epoch 37/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0206 - accuracy: 0.9900
# Epoch 38/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0106 - accuracy: 0.9950
# Epoch 39/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0264 - accuracy: 0.9875
# Epoch 40/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0203 - accuracy: 0.9900
# Epoch 41/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.1663 - accuracy: 0.9575
# Epoch 42/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0371 - accuracy: 0.9850
# Epoch 43/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0185 - accuracy: 0.9950
# Epoch 44/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0108 - accuracy: 0.9950
# Epoch 45/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0136 - accuracy: 0.9925
# Epoch 46/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0932 - accuracy: 0.9825
# Epoch 47/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0323 - accuracy: 0.9875
# Epoch 48/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0493 - accuracy: 0.9800
# Epoch 49/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0630 - accuracy: 0.9825
# Epoch 50/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0174 - accuracy: 0.9925
# Epoch 51/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0250 - accuracy: 0.9875
# Epoch 52/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0167 - accuracy: 0.9925
# Epoch 53/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0122 - accuracy: 0.9975
# Epoch 54/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0110 - accuracy: 0.9950
# Epoch 55/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0136 - accuracy: 0.9925
# Epoch 56/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0126 - accuracy: 0.9950
# Epoch 57/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.1606 - accuracy: 0.9725
# Epoch 58/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0480 - accuracy: 0.9825
# Epoch 59/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0220 - accuracy: 0.9950
# Epoch 60/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0150 - accuracy: 0.9925
# Epoch 61/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0194 - accuracy: 0.9925
# Epoch 62/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0143 - accuracy: 0.9950
# Epoch 63/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0180 - accuracy: 0.9925
# Epoch 64/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0191 - accuracy: 0.9925
# Epoch 65/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0111 - accuracy: 0.9975
# Epoch 66/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0157 - accuracy: 0.9925
# Epoch 67/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0184 - accuracy: 0.9925
# Epoch 68/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0120 - accuracy: 0.9925
# Epoch 69/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0140 - accuracy: 0.9950
# Epoch 70/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0219 - accuracy: 0.9925
# Epoch 71/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0643 - accuracy: 0.9875
# Epoch 72/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0146 - accuracy: 0.9900
# Epoch 73/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0092 - accuracy: 0.9950
# Epoch 74/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0101 - accuracy: 0.9950
# Epoch 75/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0117 - accuracy: 0.9950
# Epoch 76/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0255 - accuracy: 0.9950
# Epoch 77/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0093 - accuracy: 0.9950
# Epoch 78/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.2643 - accuracy: 0.9600
# Epoch 79/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0144 - accuracy: 0.9950
# Epoch 80/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0135 - accuracy: 0.9925
# Epoch 81/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0106 - accuracy: 0.9950
# Epoch 82/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0128 - accuracy: 0.9925
# Epoch 83/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0133 - accuracy: 0.9925
# Epoch 84/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0095 - accuracy: 0.9950
# Epoch 85/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0138 - accuracy: 0.9975
# Epoch 86/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0149 - accuracy: 0.9950
# Epoch 87/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0121 - accuracy: 0.9925
# Epoch 88/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0984 - accuracy: 0.9775
# Epoch 89/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0914 - accuracy: 0.9750
# Epoch 90/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0187 - accuracy: 0.9950
# Epoch 91/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0052 - accuracy: 1.0000
# Epoch 92/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0113 - accuracy: 0.9975
# Epoch 93/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0209 - accuracy: 0.9925
# Epoch 94/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0100 - accuracy: 0.9975
# Epoch 95/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0156 - accuracy: 0.9950
# Epoch 96/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0105 - accuracy: 0.9950
# Epoch 97/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0114 - accuracy: 0.9925
# Epoch 98/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0124 - accuracy: 0.9925
# Epoch 99/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0104 - accuracy: 0.9925
# Epoch 100/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0109 - accuracy: 0.9950
# Epoch 101/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0121 - accuracy: 0.9950
# Epoch 102/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0102 - accuracy: 0.9950
# Epoch 103/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0134 - accuracy: 0.9950
# Epoch 104/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0118 - accuracy: 0.9950
# Epoch 105/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.1056 - accuracy: 0.9800
# Epoch 106/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0183 - accuracy: 0.9925
# Epoch 107/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0097 - accuracy: 0.9950
# Epoch 108/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0267 - accuracy: 0.9875
# Epoch 109/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.1104 - accuracy: 0.9725
# Epoch 110/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0129 - accuracy: 0.9975
# Epoch 111/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0086 - accuracy: 0.9950
# Epoch 112/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0100 - accuracy: 0.9950
# Epoch 113/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0102 - accuracy: 0.9925
# Epoch 114/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0079 - accuracy: 0.9975
# Epoch 115/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0134 - accuracy: 0.9950
# Epoch 116/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0089 - accuracy: 0.9950
# Epoch 117/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0092 - accuracy: 0.9975
# Epoch 118/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0129 - accuracy: 0.9950
# Epoch 119/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0114 - accuracy: 0.9975
# Epoch 120/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0127 - accuracy: 0.9950
# Epoch 121/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0088 - accuracy: 0.9950
# Epoch 122/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0091 - accuracy: 0.9925
# Epoch 123/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0116 - accuracy: 0.9925
# Epoch 124/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0125 - accuracy: 0.9900
# Epoch 125/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0076 - accuracy: 0.9975
# Epoch 126/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0038 - accuracy: 0.9975
# Epoch 127/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0762 - accuracy: 0.9775
# Epoch 128/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0110 - accuracy: 0.9950
# Epoch 129/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0075 - accuracy: 0.9975
# Epoch 130/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0111 - accuracy: 0.9975
# Epoch 131/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0082 - accuracy: 0.9950
# Epoch 132/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0067 - accuracy: 0.9975
# Epoch 133/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0132 - accuracy: 0.9950
# Epoch 134/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0086 - accuracy: 0.9950
# Epoch 135/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0089 - accuracy: 0.9950
# Epoch 136/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0098 - accuracy: 0.9925
# Epoch 137/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0066 - accuracy: 0.9950
# Epoch 138/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0110 - accuracy: 0.9975
# Epoch 139/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.1227 - accuracy: 0.9850
# Epoch 140/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0125 - accuracy: 0.9975
# Epoch 141/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0093 - accuracy: 0.9925
# Epoch 142/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0103 - accuracy: 0.9950
# Epoch 143/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0076 - accuracy: 0.9975
# Epoch 144/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0095 - accuracy: 0.9950
# Epoch 145/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0097 - accuracy: 0.9950
# Epoch 146/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0090 - accuracy: 0.9925
# Epoch 147/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0089 - accuracy: 0.9975
# Epoch 148/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0152 - accuracy: 0.9950
# Epoch 149/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0064 - accuracy: 0.9975
# Epoch 150/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0107 - accuracy: 0.9950
# Epoch 151/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0106 - accuracy: 0.9975
# Epoch 152/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.1013 - accuracy: 0.9800
# Epoch 153/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0168 - accuracy: 0.9950
# Epoch 154/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0122 - accuracy: 0.9950
# Epoch 155/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0317 - accuracy: 0.9875
# Epoch 156/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0073 - accuracy: 0.9975
# Epoch 157/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0094 - accuracy: 0.9950
# Epoch 158/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0121 - accuracy: 0.9975
# Epoch 159/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0090 - accuracy: 0.9975
# Epoch 160/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0066 - accuracy: 0.9975
# Epoch 161/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0065 - accuracy: 1.0000
# Epoch 162/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0089 - accuracy: 0.9950
# Epoch 163/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0144 - accuracy: 0.9950
# Epoch 164/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0084 - accuracy: 0.9950
# Epoch 165/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0072 - accuracy: 0.9950
# Epoch 166/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0067 - accuracy: 0.9950
# Epoch 167/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0069 - accuracy: 0.9950
# Epoch 168/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1956 - accuracy: 0.9700
# Epoch 169/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0089 - accuracy: 0.9975
# Epoch 170/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0086 - accuracy: 0.9950
# Epoch 171/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0076 - accuracy: 0.9975
# Epoch 172/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0125 - accuracy: 0.9950
# Epoch 173/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0073 - accuracy: 1.0000
# Epoch 174/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0105 - accuracy: 0.9950
# Epoch 175/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0069 - accuracy: 0.9975
# Epoch 176/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0067 - accuracy: 0.9950
# Epoch 177/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0178 - accuracy: 0.9975
# Epoch 178/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0088 - accuracy: 0.9950
# Epoch 179/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0072 - accuracy: 0.9950
# Epoch 180/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0060 - accuracy: 0.9975
# Epoch 181/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0062 - accuracy: 0.9950
# Epoch 182/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0382 - accuracy: 0.9950
# Epoch 183/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0410 - accuracy: 0.9850
# Epoch 184/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0079 - accuracy: 0.9975
# Epoch 185/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0834 - accuracy: 0.9875
# Epoch 186/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0118 - accuracy: 0.9950
# Epoch 187/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0082 - accuracy: 0.9950
# Epoch 188/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0057 - accuracy: 0.9975
# Epoch 189/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0069 - accuracy: 1.0000
# Epoch 190/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0071 - accuracy: 0.9975
# Epoch 191/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0120 - accuracy: 0.9975
# Epoch 192/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0109 - accuracy: 0.9975
# Epoch 193/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.1264 - accuracy: 0.9775
# Epoch 194/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0111 - accuracy: 0.9950
# Epoch 195/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0061 - accuracy: 0.9975
# Epoch 196/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0052 - accuracy: 0.9975
# Epoch 197/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0064 - accuracy: 0.9950
# Epoch 198/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0122 - accuracy: 0.9925
# Epoch 199/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0051 - accuracy: 0.9975
# Epoch 200/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0150 - accuracy: 0.9950

# %% [markdown]
# #### FFDNN Model Summary & layers

# %%
print(DFFNN_model.summary())
tf.keras.utils.plot_model(DFFNN_model,show_shapes=True,
                          show_layer_names=True,
                          rankdir="TB",expand_nested=True,dpi=96,)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 96)                288
# _________________________________________________________________
# dense_7 (Dense)              (None, 200)               19400
# _________________________________________________________________
# dense_8 (Dense)              (None, 96)                19296
# _________________________________________________________________
# dense_9 (Dense)              (None, 24)                2328
# _________________________________________________________________
# dense_10 (Dense)             (None, 2)                 50
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 41,365
# Trainable params: 41,365
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
visualize(sample,target, DFFNN_model)

# %% [markdown]
# ### Deep Neural Network with L2-regularization
#
# $\lambda = 0.01, 2, 100$

# %% [markdown]
# ####  Regularization with $\lambda = 0.01$

# %%
lambda_l2 = 0.01
DFFNN_model = keras.Sequential()

DFFNN_model.add(keras.layers.Dense(96,input_shape=(2,),
                                          activation = tf.keras.activations.tanh,
                                          activity_regularizer = tf.keras.regularizers.L1L2(l1 = 0.0, l2=lambda_l2),))
DFFNN_model.add(keras.layers.Dense(200,input_shape=(96,),
                                          activation = tf.keras.activations.tanh,
                                  activity_regularizer = tf.keras.regularizers.L1L2(l1 = 0.0, l2=lambda_l2),))
DFFNN_model.add(keras.layers.Dense(96,input_shape=(200,),
                                          activation = tf.keras.activations.relu,
                                  activity_regularizer = tf.keras.regularizers.L1L2(l1 = 0.0, l2=lambda_l2),))
DFFNN_model.add(keras.layers.Dense(24,input_shape=(48,),
                                          activation = tf.keras.activations.relu,
                                  activity_regularizer = tf.keras.regularizers.L1L2(l1 = 0.0, l2=lambda_l2),))
DFFNN_model.add(keras.layers.Dense(2,input_shape=(24,),
                                          activation = tf.keras.activations.relu,
                                  activity_regularizer = tf.keras.regularizers.L1L2(l1 = 0.0, l2=lambda_l2),))

DFFNN_model.add(keras.layers.Dense(1,input_shape=(2,),
                                          activation = tf.keras.activations.sigmoid,))

DFFNN_model.compile(optimizer="adam",loss= 'binary_crossentropy', metrics=['accuracy'])

# Train the model
value_epoches = DFFNN_model.fit(sample, target, epochs=200,batch_size=1,
                                        shuffle=True, verbose = 1, validation_split=0.0)
# Out:
# Train on 400 samples
# Epoch 1/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.6236 - accuracy: 0.7000
# Epoch 2/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.5849 - accuracy: 0.8150
# Epoch 3/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.4970 - accuracy: 0.8900
# Epoch 4/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.4258 - accuracy: 0.9450
# Epoch 5/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.3889 - accuracy: 0.9450
# Epoch 6/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.3257 - accuracy: 0.9725
# Epoch 7/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.3306 - accuracy: 0.9525
# Epoch 8/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.3312 - accuracy: 0.9375
# Epoch 9/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.2984 - accuracy: 0.9725
# Epoch 10/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.2559 - accuracy: 0.9625
# Epoch 11/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.2360 - accuracy: 0.9625
# Epoch 12/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.2415 - accuracy: 0.9600
# Epoch 13/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.2069 - accuracy: 0.9700
# Epoch 14/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1820 - accuracy: 0.9775
# Epoch 15/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1863 - accuracy: 0.9700
# Epoch 16/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1609 - accuracy: 0.9825
# Epoch 17/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1949 - accuracy: 0.9625
# Epoch 18/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1712 - accuracy: 0.9725
# Epoch 19/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1572 - accuracy: 0.9800
# Epoch 20/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1846 - accuracy: 0.9600
# Epoch 21/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.2245 - accuracy: 0.9500
# Epoch 22/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1360 - accuracy: 0.9875
# Epoch 23/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1427 - accuracy: 0.9700
# Epoch 24/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1508 - accuracy: 0.9725
# Epoch 25/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1354 - accuracy: 0.9750
# Epoch 26/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1235 - accuracy: 0.9750
# Epoch 27/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1243 - accuracy: 0.9825
# Epoch 28/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1107 - accuracy: 0.9850
# Epoch 29/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1425 - accuracy: 0.9700
# Epoch 30/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1017 - accuracy: 0.9900
# Epoch 31/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1419 - accuracy: 0.9700
# Epoch 32/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1546 - accuracy: 0.9675
# Epoch 33/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1577 - accuracy: 0.9650
# Epoch 34/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1104 - accuracy: 0.9825
# Epoch 35/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.1182 - accuracy: 0.9825
# Epoch 36/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.1101 - accuracy: 0.9825
# Epoch 37/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1007 - accuracy: 0.9825
# Epoch 38/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0941 - accuracy: 0.9875
# Epoch 39/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0999 - accuracy: 0.9800
# Epoch 40/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0988 - accuracy: 0.9825
# Epoch 41/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0735 - accuracy: 0.9975
# Epoch 42/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.2160 - accuracy: 0.9525
# Epoch 43/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1175 - accuracy: 0.9800
# Epoch 44/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1173 - accuracy: 0.9725
# Epoch 45/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0810 - accuracy: 0.9900
# Epoch 46/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1330 - accuracy: 0.9675
# Epoch 47/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0851 - accuracy: 0.9850
# Epoch 48/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0856 - accuracy: 0.9875
# Epoch 49/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0823 - accuracy: 0.9875
# Epoch 50/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0882 - accuracy: 0.9850
# Epoch 51/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0836 - accuracy: 0.9875
# Epoch 52/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0998 - accuracy: 0.9800
# Epoch 53/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0924 - accuracy: 0.9800
# Epoch 54/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.1439 - accuracy: 0.9550
# Epoch 55/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1533 - accuracy: 0.9600
# Epoch 56/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.1076 - accuracy: 0.9775
# Epoch 57/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0773 - accuracy: 0.9925
# Epoch 58/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0865 - accuracy: 0.9850
# Epoch 59/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0721 - accuracy: 0.9875
# Epoch 60/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0867 - accuracy: 0.9825
# Epoch 61/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0706 - accuracy: 0.9875
# Epoch 62/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0744 - accuracy: 0.9875
# Epoch 63/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0845 - accuracy: 0.9875
# Epoch 64/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0716 - accuracy: 0.9850
# Epoch 65/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0738 - accuracy: 0.9825
# Epoch 66/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0786 - accuracy: 0.9875
# Epoch 67/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.1411 - accuracy: 0.9700
# Epoch 68/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0871 - accuracy: 0.9825
# Epoch 69/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0713 - accuracy: 0.9925
# Epoch 70/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0745 - accuracy: 0.9875
# Epoch 71/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0679 - accuracy: 0.9875
# Epoch 72/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0956 - accuracy: 0.9825
# Epoch 73/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.3143 - accuracy: 0.9050
# Epoch 74/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.1640 - accuracy: 0.9550
# Epoch 75/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.1107 - accuracy: 0.9700
# Epoch 76/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0997 - accuracy: 0.9850
# Epoch 77/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0841 - accuracy: 0.9850
# Epoch 78/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0830 - accuracy: 0.9825
# Epoch 79/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0778 - accuracy: 0.9825
# Epoch 80/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0836 - accuracy: 0.9825
# Epoch 81/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0901 - accuracy: 0.9775
# Epoch 82/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.1197 - accuracy: 0.9700
# Epoch 83/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0925 - accuracy: 0.9850
# Epoch 84/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0677 - accuracy: 0.9900
# Epoch 85/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0664 - accuracy: 0.9850
# Epoch 86/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0692 - accuracy: 0.9850
# Epoch 87/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.1019 - accuracy: 0.9675
# Epoch 88/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0701 - accuracy: 0.9900
# Epoch 89/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0588 - accuracy: 0.9925
# Epoch 90/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.1143 - accuracy: 0.9700
# Epoch 91/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0810 - accuracy: 0.9825
# Epoch 92/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0815 - accuracy: 0.9825
# Epoch 93/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.1633 - accuracy: 0.9625
# Epoch 94/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0793 - accuracy: 0.9900
# Epoch 95/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0595 - accuracy: 0.9925
# Epoch 96/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0631 - accuracy: 0.9875
# Epoch 97/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0729 - accuracy: 0.9825
# Epoch 98/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0605 - accuracy: 0.9875
# Epoch 99/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.1015 - accuracy: 0.9725
# Epoch 100/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0581 - accuracy: 0.9900
# Epoch 101/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0608 - accuracy: 0.9875
# Epoch 102/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0642 - accuracy: 0.9875
# Epoch 103/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0559 - accuracy: 0.9950
# Epoch 104/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.1375 - accuracy: 0.9625
# Epoch 105/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1058 - accuracy: 0.9775
# Epoch 106/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0736 - accuracy: 0.9825
# Epoch 107/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0627 - accuracy: 0.9825
# Epoch 108/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0706 - accuracy: 0.9850
# Epoch 109/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0813 - accuracy: 0.9825
# Epoch 110/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0629 - accuracy: 0.9875
# Epoch 111/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0570 - accuracy: 0.9900
# Epoch 112/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0555 - accuracy: 0.9900
# Epoch 113/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0810 - accuracy: 0.9875
# Epoch 114/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.2270 - accuracy: 0.9525
# Epoch 115/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0713 - accuracy: 0.9825
# Epoch 116/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0517 - accuracy: 0.9975
# Epoch 117/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0614 - accuracy: 0.9875
# Epoch 118/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0590 - accuracy: 0.9875
# Epoch 119/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0711 - accuracy: 0.9875
# Epoch 120/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0668 - accuracy: 0.9875
# Epoch 121/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0587 - accuracy: 0.9875
# Epoch 122/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0595 - accuracy: 0.9900
# Epoch 123/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0590 - accuracy: 0.9875
# Epoch 124/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0535 - accuracy: 0.9900
# Epoch 125/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0588 - accuracy: 0.9900
# Epoch 126/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0681 - accuracy: 0.9875
# Epoch 127/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.0647 - accuracy: 0.9850
# Epoch 128/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0596 - accuracy: 0.9850
# Epoch 129/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.1519 - accuracy: 0.9575
# Epoch 130/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.2727 - accuracy: 0.9400
# Epoch 131/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0855 - accuracy: 0.9825
# Epoch 132/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0674 - accuracy: 0.9850
# Epoch 133/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0582 - accuracy: 0.9900
# Epoch 134/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0638 - accuracy: 0.9850
# Epoch 135/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0479 - accuracy: 0.9950
# Epoch 136/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0444 - accuracy: 0.9975
# Epoch 137/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0543 - accuracy: 0.9875
# Epoch 138/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0916 - accuracy: 0.9825
# Epoch 139/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0758 - accuracy: 0.9875
# Epoch 140/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0542 - accuracy: 0.9875
# Epoch 141/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0510 - accuracy: 0.9900
# Epoch 142/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0534 - accuracy: 0.9925
# Epoch 143/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.1940 - accuracy: 0.9475
# Epoch 144/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.2657 - accuracy: 0.9375
# Epoch 145/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0935 - accuracy: 0.9850
# Epoch 146/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0546 - accuracy: 0.9925
# Epoch 147/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0586 - accuracy: 0.9925
# Epoch 148/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0535 - accuracy: 0.9925
# Epoch 149/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0503 - accuracy: 0.9900
# Epoch 150/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0548 - accuracy: 0.9900
# Epoch 151/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0843 - accuracy: 0.9775
# Epoch 152/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.1499 - accuracy: 0.9675
# Epoch 153/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0639 - accuracy: 0.9900
# Epoch 154/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0534 - accuracy: 0.9875
# Epoch 155/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0528 - accuracy: 0.9900
# Epoch 156/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0776 - accuracy: 0.9775
# Epoch 157/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0910 - accuracy: 0.9750
# Epoch 158/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0524 - accuracy: 0.9900
# Epoch 159/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0477 - accuracy: 0.9900
# Epoch 160/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0927 - accuracy: 0.9800
# Epoch 161/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.2567 - accuracy: 0.9200
# Epoch 162/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0882 - accuracy: 0.9900
# Epoch 163/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0631 - accuracy: 0.9900
# Epoch 164/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0529 - accuracy: 0.9900
# Epoch 165/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0537 - accuracy: 0.9900
# Epoch 166/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0505 - accuracy: 0.9925
# Epoch 167/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0625 - accuracy: 0.9800
# Epoch 168/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0559 - accuracy: 0.9900
# Epoch 169/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0454 - accuracy: 0.9950
# Epoch 170/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0757 - accuracy: 0.9825
# Epoch 171/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.1064 - accuracy: 0.9675
# Epoch 172/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0701 - accuracy: 0.9825
# Epoch 173/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.1759 - accuracy: 0.9575
# Epoch 174/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0690 - accuracy: 0.9800
# Epoch 175/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0563 - accuracy: 0.9850
# Epoch 176/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0518 - accuracy: 0.9875
# Epoch 177/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0505 - accuracy: 0.9925
# Epoch 178/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0479 - accuracy: 0.9950
# Epoch 179/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0557 - accuracy: 0.9900
# Epoch 180/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0532 - accuracy: 0.9950
# Epoch 181/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0516 - accuracy: 0.9850
# Epoch 182/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0469 - accuracy: 0.9900
# Epoch 183/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.1274 - accuracy: 0.9725
# Epoch 184/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0561 - accuracy: 0.9900
# Epoch 185/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0516 - accuracy: 0.9925
# Epoch 186/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0941 - accuracy: 0.9775
# Epoch 187/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0665 - accuracy: 0.9925
# Epoch 188/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0606 - accuracy: 0.9850
# Epoch 189/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0475 - accuracy: 0.9900
# Epoch 190/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0550 - accuracy: 0.9900
# Epoch 191/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0590 - accuracy: 0.9800
# Epoch 192/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0733 - accuracy: 0.9825
# Epoch 193/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.1188 - accuracy: 0.9700
# Epoch 194/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0471 - accuracy: 0.9950
# Epoch 195/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0509 - accuracy: 0.9925
# Epoch 196/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0503 - accuracy: 0.9925
# Epoch 197/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0444 - accuracy: 0.9925
# Epoch 198/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0529 - accuracy: 0.9875
# Epoch 199/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0548 - accuracy: 0.9900
# Epoch 200/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0493 - accuracy: 0.9875

# %%
visualize(sample,target, DFFNN_model)

# %% [markdown]
# ####  Regularization with $\lambda = 2$

# %%
lambda_l2 = 2
DFFNN_model = keras.Sequential()

DFFNN_model.add(keras.layers.Dense(96,input_shape=(2,),
                                          activation = tf.keras.activations.tanh,
                                          activity_regularizer = tf.keras.regularizers.L1L2(l1 = 0.0, l2=lambda_l2),))
DFFNN_model.add(keras.layers.Dense(200,input_shape=(96,),
                                          activation = tf.keras.activations.tanh,
                                  activity_regularizer = tf.keras.regularizers.L1L2(l1 = 0.0, l2=lambda_l2),))
DFFNN_model.add(keras.layers.Dense(96,input_shape=(200,),
                                          activation = tf.keras.activations.relu,
                                  activity_regularizer = tf.keras.regularizers.L1L2(l1 = 0.0, l2=lambda_l2),))
DFFNN_model.add(keras.layers.Dense(24,input_shape=(48,),
                                          activation = tf.keras.activations.relu,
                                  activity_regularizer = tf.keras.regularizers.L1L2(l1 = 0.0, l2=lambda_l2),))
DFFNN_model.add(keras.layers.Dense(2,input_shape=(24,),
                                          activation = tf.keras.activations.relu,
                                  activity_regularizer = tf.keras.regularizers.L1L2(l1 = 0.0, l2=lambda_l2),))

DFFNN_model.add(keras.layers.Dense(1,input_shape=(2,),
                                          activation = tf.keras.activations.sigmoid,))

DFFNN_model.compile(optimizer="adam",loss= 'binary_crossentropy', metrics=['accuracy'])

# Train the model
value_epoches = DFFNN_model.fit(sample, target, epochs=200,batch_size=1,
                                        shuffle=True, verbose = 1, validation_split=0.0)
# Out:
# Train on 400 samples
# Epoch 1/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 1.2663 - accuracy: 0.4750
# Epoch 2/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.7285 - accuracy: 0.4775
# Epoch 3/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6943 - accuracy: 0.4750
# Epoch 4/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6934 - accuracy: 0.5025
# Epoch 5/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6934 - accuracy: 0.4675
# Epoch 6/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6934 - accuracy: 0.4850
# Epoch 7/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4700
# Epoch 8/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4825
# Epoch 9/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6933 - accuracy: 0.4600
# Epoch 10/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6934 - accuracy: 0.4825
# Epoch 11/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6935 - accuracy: 0.4750
# Epoch 12/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4275
# Epoch 13/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6936 - accuracy: 0.4825
# Epoch 14/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6934 - accuracy: 0.4750
# Epoch 15/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6937 - accuracy: 0.4525
# Epoch 16/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6934 - accuracy: 0.4775
# Epoch 17/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6936 - accuracy: 0.4975
# Epoch 18/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6937 - accuracy: 0.4900
# Epoch 19/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6936 - accuracy: 0.4550
# Epoch 20/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6939 - accuracy: 0.4575
# Epoch 21/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6934 - accuracy: 0.5000
# Epoch 22/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6935 - accuracy: 0.4675
# Epoch 23/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6936 - accuracy: 0.4775
# Epoch 24/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6935 - accuracy: 0.4675
# Epoch 25/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6936 - accuracy: 0.4875
# Epoch 26/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6936 - accuracy: 0.4500
# Epoch 27/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6934 - accuracy: 0.4875
# Epoch 28/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6937 - accuracy: 0.4625
# Epoch 29/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6935 - accuracy: 0.4725
# Epoch 30/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6935 - accuracy: 0.4850
# Epoch 31/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6935 - accuracy: 0.4575
# Epoch 32/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6935 - accuracy: 0.4700
# Epoch 33/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6935 - accuracy: 0.4500
# Epoch 34/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6936 - accuracy: 0.4650
# Epoch 35/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6934 - accuracy: 0.4775
# Epoch 36/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6934 - accuracy: 0.4825
# Epoch 37/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6936 - accuracy: 0.4725
# Epoch 38/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6934 - accuracy: 0.4525
# Epoch 39/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6935 - accuracy: 0.4450
# Epoch 40/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6935 - accuracy: 0.4475
# Epoch 41/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4675
# Epoch 42/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6935 - accuracy: 0.4600
# Epoch 43/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4950
# Epoch 44/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4850
# Epoch 45/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6935 - accuracy: 0.4725
# Epoch 46/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6935 - accuracy: 0.4800
# Epoch 47/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6934 - accuracy: 0.4725
# Epoch 48/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6935 - accuracy: 0.4300
# Epoch 49/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6934 - accuracy: 0.4825
# Epoch 50/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6933 - accuracy: 0.5000
# Epoch 51/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6936 - accuracy: 0.4625
# Epoch 52/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6933 - accuracy: 0.4700
# Epoch 53/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6933 - accuracy: 0.4550
# Epoch 54/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6938 - accuracy: 0.4850
# Epoch 55/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.5000
# Epoch 56/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4725
# Epoch 57/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4625
# Epoch 58/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6935 - accuracy: 0.4600
# Epoch 59/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6940 - accuracy: 0.4950
# Epoch 60/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6933 - accuracy: 0.4850
# Epoch 61/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6933 - accuracy: 0.4875
# Epoch 62/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6935 - accuracy: 0.4700
# Epoch 63/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6937 - accuracy: 0.4550
# Epoch 64/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4400
# Epoch 65/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4850
# Epoch 66/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6936 - accuracy: 0.4850
# Epoch 67/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4950
# Epoch 68/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4825
# Epoch 69/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6935 - accuracy: 0.4625
# Epoch 70/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4625
# Epoch 71/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4725
# Epoch 72/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4700
# Epoch 73/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6937 - accuracy: 0.4925
# Epoch 74/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4825
# Epoch 75/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6933 - accuracy: 0.4725
# Epoch 76/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4900
# Epoch 77/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6936 - accuracy: 0.4425
# Epoch 78/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6938 - accuracy: 0.4700
# Epoch 79/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4725
# Epoch 80/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4825
# Epoch 81/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6943 - accuracy: 0.4900
# Epoch 82/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4450
# Epoch 83/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6933 - accuracy: 0.4925
# Epoch 84/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4850
# Epoch 85/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4950
# Epoch 86/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6933 - accuracy: 0.4725
# Epoch 87/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6936 - accuracy: 0.4550
# Epoch 88/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4875
# Epoch 89/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6935 - accuracy: 0.4550
# Epoch 90/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6935 - accuracy: 0.4875
# Epoch 91/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4875
# Epoch 92/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6935 - accuracy: 0.4775
# Epoch 93/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6940 - accuracy: 0.4750
# Epoch 94/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6933 - accuracy: 0.4900
# Epoch 95/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4525
# Epoch 96/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4950
# Epoch 97/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4675
# Epoch 98/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6935 - accuracy: 0.4725
# Epoch 99/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6936 - accuracy: 0.4350
# Epoch 100/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4775
# Epoch 101/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4650
# Epoch 102/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4700
# Epoch 103/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6936 - accuracy: 0.4550
# Epoch 104/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6936 - accuracy: 0.4525
# Epoch 105/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6936 - accuracy: 0.4600
# Epoch 106/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4925
# Epoch 107/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.5000
# Epoch 108/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4600
# Epoch 109/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6935 - accuracy: 0.4625
# Epoch 110/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6935 - accuracy: 0.4650
# Epoch 111/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4725
# Epoch 112/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4925
# Epoch 113/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6948 - accuracy: 0.4825
# Epoch 114/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6935 - accuracy: 0.4350
# Epoch 115/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6933 - accuracy: 0.4925
# Epoch 116/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4875
# Epoch 117/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4675
# Epoch 118/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4650
# Epoch 119/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.5000
# Epoch 120/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4700
# Epoch 121/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4875
# Epoch 122/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6935 - accuracy: 0.4550
# Epoch 123/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6935 - accuracy: 0.4575
# Epoch 124/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4225
# Epoch 125/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4425
# Epoch 126/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6935 - accuracy: 0.4850
# Epoch 127/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6952 - accuracy: 0.4725
# Epoch 128/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.5000
# Epoch 129/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4675
# Epoch 130/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4700
# Epoch 131/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4625
# Epoch 132/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4825
# Epoch 133/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4650
# Epoch 134/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6935 - accuracy: 0.4600
# Epoch 135/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4675
# Epoch 136/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4850
# Epoch 137/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6935 - accuracy: 0.4675
# Epoch 138/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6943 - accuracy: 0.5000
# Epoch 139/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4400
# Epoch 140/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4700
# Epoch 141/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6933 - accuracy: 0.4425
# Epoch 142/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6933 - accuracy: 0.4525
# Epoch 143/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4950
# Epoch 144/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4900
# Epoch 145/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4850
# Epoch 146/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6943 - accuracy: 0.4725
# Epoch 147/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4875
# Epoch 148/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6933 - accuracy: 0.4775
# Epoch 149/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4675
# Epoch 150/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4900
# Epoch 151/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6935 - accuracy: 0.4775
# Epoch 152/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4825
# Epoch 153/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6935 - accuracy: 0.4750
# Epoch 154/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.5000
# Epoch 155/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6935 - accuracy: 0.4600
# Epoch 156/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6933 - accuracy: 0.4700
# Epoch 157/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6935 - accuracy: 0.4825
# Epoch 158/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4825
# Epoch 159/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6935 - accuracy: 0.5000
# Epoch 160/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6936 - accuracy: 0.4900
# Epoch 161/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4900
# Epoch 162/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4675
# Epoch 163/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4750
# Epoch 164/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4650
# Epoch 165/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4875
# Epoch 166/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6936 - accuracy: 0.4675
# Epoch 167/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4450
# Epoch 168/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4850
# Epoch 169/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6935 - accuracy: 0.4725
# Epoch 170/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6944 - accuracy: 0.4775
# Epoch 171/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6933 - accuracy: 0.5000
# Epoch 172/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4850
# Epoch 173/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4675
# Epoch 174/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4650
# Epoch 175/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4700
# Epoch 176/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.5000
# Epoch 177/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6935 - accuracy: 0.4625
# Epoch 178/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6935 - accuracy: 0.4800
# Epoch 179/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6941 - accuracy: 0.4900
# Epoch 180/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6933 - accuracy: 0.4775
# Epoch 181/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6935 - accuracy: 0.4325
# Epoch 182/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6934 - accuracy: 0.4525
# Epoch 183/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6935 - accuracy: 0.4975
# Epoch 184/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.6934 - accuracy: 0.4775
# Epoch 185/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4700
# Epoch 186/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6936 - accuracy: 0.4775
# Epoch 187/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6935 - accuracy: 0.4825
# Epoch 188/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4825
# Epoch 189/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6934 - accuracy: 0.4850
# Epoch 190/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6936 - accuracy: 0.4925
# Epoch 191/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4675
# Epoch 192/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4975
# Epoch 193/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6938 - accuracy: 0.4700
# Epoch 194/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4375
# Epoch 195/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4850
# Epoch 196/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.5000
# Epoch 197/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4725
# Epoch 198/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6935 - accuracy: 0.4675
# Epoch 199/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6935 - accuracy: 0.4825
# Epoch 200/200
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.6934 - accuracy: 0.4600

# %%
visualize(sample,target, DFFNN_model)

# %% [markdown]
# ####  Regularization with $\lambda = 100$

# %%
lambda_l2 = 100
DFFNN_model = keras.Sequential()

DFFNN_model.add(keras.layers.Dense(96,input_shape=(2,),
                                          activation = tf.keras.activations.tanh,
                                          activity_regularizer = tf.keras.regularizers.L1L2(l1 = 0.0, l2=lambda_l2),))
DFFNN_model.add(keras.layers.Dense(200,input_shape=(96,),
                                          activation = tf.keras.activations.tanh,
                                  activity_regularizer = tf.keras.regularizers.L1L2(l1 = 0.0, l2=lambda_l2),))
DFFNN_model.add(keras.layers.Dense(96,input_shape=(200,),
                                          activation = tf.keras.activations.relu,
                                  activity_regularizer = tf.keras.regularizers.L1L2(l1 = 0.0, l2=lambda_l2),))
DFFNN_model.add(keras.layers.Dense(24,input_shape=(48,),
                                          activation = tf.keras.activations.relu,
                                  activity_regularizer = tf.keras.regularizers.L1L2(l1 = 0.0, l2=lambda_l2),))
DFFNN_model.add(keras.layers.Dense(2,input_shape=(24,),
                                          activation = tf.keras.activations.relu,
                                  activity_regularizer = tf.keras.regularizers.L1L2(l1 = 0.0, l2=lambda_l2),))

DFFNN_model.add(keras.layers.Dense(1,input_shape=(2,),
                                          activation = tf.keras.activations.sigmoid,))

DFFNN_model.compile(optimizer="adam",loss= 'binary_crossentropy', metrics=['accuracy'])

# Train the model
value_epoches = DFFNN_model.fit(sample, target, epochs=200,batch_size=1,
                                        shuffle=True, verbose = 1, validation_split=0.0)
# Out:
# Train on 400 samples
# Epoch 1/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 28.6931 - accuracy: 0.4800
# Epoch 2/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 2.3322 - accuracy: 0.4900
# Epoch 3/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.7446 - accuracy: 0.4425
# Epoch 4/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6940 - accuracy: 0.4850
# Epoch 5/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6935 - accuracy: 0.4800
# Epoch 6/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6933 - accuracy: 0.4825
# Epoch 7/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6933 - accuracy: 0.4575
# Epoch 8/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6935 - accuracy: 0.4625
# Epoch 9/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6933 - accuracy: 0.4650
# Epoch 10/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6934 - accuracy: 0.4925
# Epoch 11/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6934 - accuracy: 0.4875
# Epoch 12/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.7129 - accuracy: 0.4825
# Epoch 13/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6973 - accuracy: 0.4750
# Epoch 14/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6978 - accuracy: 0.5000
# Epoch 15/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6946 - accuracy: 0.4525
# Epoch 16/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.7272 - accuracy: 0.4625
# Epoch 17/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6936 - accuracy: 0.4750
# Epoch 18/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.7006 - accuracy: 0.4800
# Epoch 19/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.7122 - accuracy: 0.4600
# Epoch 20/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.7091 - accuracy: 0.4625
# Epoch 21/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6990 - accuracy: 0.4650
# Epoch 22/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.7045 - accuracy: 0.4775
# Epoch 23/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.7135 - accuracy: 0.4650
# Epoch 24/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.7017 - accuracy: 0.5000
# Epoch 25/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.7016 - accuracy: 0.4750
# Epoch 26/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.6982 - accuracy: 0.4450
# Epoch 27/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.7054 - accuracy: 0.4700
# Epoch 28/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6973 - accuracy: 0.4325
# Epoch 29/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.7073 - accuracy: 0.4650
# Epoch 30/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6973 - accuracy: 0.4600
# Epoch 31/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.6969 - accuracy: 0.4700
# Epoch 32/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.6977 - accuracy: 0.4725
# Epoch 33/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6974 - accuracy: 0.4675
# Epoch 34/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6996 - accuracy: 0.4900
# Epoch 35/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6954 - accuracy: 0.4800
# Epoch 36/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7122 - accuracy: 0.4475
# Epoch 37/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6944 - accuracy: 0.4450
# Epoch 38/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6974 - accuracy: 0.4650
# Epoch 39/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6968 - accuracy: 0.4650
# Epoch 40/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6964 - accuracy: 0.4600
# Epoch 41/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6961 - accuracy: 0.4525
# Epoch 42/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7000 - accuracy: 0.4800
# Epoch 43/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.6954 - accuracy: 0.4750
# Epoch 44/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6972 - accuracy: 0.4375
# Epoch 45/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7096 - accuracy: 0.4425
# Epoch 46/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6935 - accuracy: 0.4700
# Epoch 47/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6939 - accuracy: 0.4925
# Epoch 48/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7703 - accuracy: 0.4300
# Epoch 49/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.4550
# Epoch 50/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.4975
# Epoch 51/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6933 - accuracy: 0.4675
# Epoch 52/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6933 - accuracy: 0.5000
# Epoch 53/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6933 - accuracy: 0.4775
# Epoch 54/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.4800
# Epoch 55/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6933 - accuracy: 0.4800
# Epoch 56/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.5000
# Epoch 57/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7054 - accuracy: 0.4375
# Epoch 58/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.7024 - accuracy: 0.4800
# Epoch 59/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6934 - accuracy: 0.4650
# Epoch 60/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6947 - accuracy: 0.4875
# Epoch 61/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7047 - accuracy: 0.4575
# Epoch 62/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7013 - accuracy: 0.5000
# Epoch 63/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6937 - accuracy: 0.4725
# Epoch 64/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6935 - accuracy: 0.4750
# Epoch 65/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6961 - accuracy: 0.4850
# Epoch 66/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7028 - accuracy: 0.4800
# Epoch 67/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6957 - accuracy: 0.4950
# Epoch 68/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6970 - accuracy: 0.4200
# Epoch 69/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6964 - accuracy: 0.4650
# Epoch 70/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6970 - accuracy: 0.5000
# Epoch 71/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6958 - accuracy: 0.4775
# Epoch 72/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7672 - accuracy: 0.4850
# Epoch 73/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.4825
# Epoch 74/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.4850
# Epoch 75/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6933 - accuracy: 0.4675
# Epoch 76/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.4900
# Epoch 77/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.4700
# Epoch 78/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.4675
# Epoch 79/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6933 - accuracy: 0.4800
# Epoch 80/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6952 - accuracy: 0.4875
# Epoch 81/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7078 - accuracy: 0.4625
# Epoch 82/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6941 - accuracy: 0.4850
# Epoch 83/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6974 - accuracy: 0.4600
# Epoch 84/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6936 - accuracy: 0.4575
# Epoch 85/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7010 - accuracy: 0.4550
# Epoch 86/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7077 - accuracy: 0.4725
# Epoch 87/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6935 - accuracy: 0.4225
# Epoch 88/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6955 - accuracy: 0.4725
# Epoch 89/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6937 - accuracy: 0.4825
# Epoch 90/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7051 - accuracy: 0.4750
# Epoch 91/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6973 - accuracy: 0.4700
# Epoch 92/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6935 - accuracy: 0.4550
# Epoch 93/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.4875
# Epoch 94/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6987 - accuracy: 0.4750
# Epoch 95/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6999 - accuracy: 0.4650
# Epoch 96/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6943 - accuracy: 0.4725
# Epoch 97/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6963 - accuracy: 0.4650
# Epoch 98/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7196 - accuracy: 0.4750
# Epoch 99/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7034 - accuracy: 0.4650
# Epoch 100/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6933 - accuracy: 0.4475
# Epoch 101/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.5000
# Epoch 102/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6935 - accuracy: 0.4850
# Epoch 103/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6995 - accuracy: 0.4775
# Epoch 104/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6935 - accuracy: 0.4325
# Epoch 105/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6964 - accuracy: 0.4825
# Epoch 106/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7090 - accuracy: 0.4550
# Epoch 107/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6936 - accuracy: 0.4700
# Epoch 108/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6944 - accuracy: 0.4800
# Epoch 109/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6953 - accuracy: 0.4625
# Epoch 110/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6950 - accuracy: 0.4400
# Epoch 111/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6947 - accuracy: 0.4600
# Epoch 112/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7212 - accuracy: 0.4825
# Epoch 113/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6935 - accuracy: 0.4800
# Epoch 114/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6935 - accuracy: 0.4950
# Epoch 115/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.4700
# Epoch 116/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6977 - accuracy: 0.4400
# Epoch 117/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6945 - accuracy: 0.4925
# Epoch 118/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6985 - accuracy: 0.4850
# Epoch 119/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6939 - accuracy: 0.4750
# Epoch 120/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7214 - accuracy: 0.4925
# Epoch 121/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6942 - accuracy: 0.4600
# Epoch 122/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.4900
# Epoch 123/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.4825
# Epoch 124/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6935 - accuracy: 0.4825
# Epoch 125/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6968 - accuracy: 0.4925
# Epoch 126/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7058 - accuracy: 0.4650
# Epoch 127/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6942 - accuracy: 0.4525
# Epoch 128/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.4775
# Epoch 129/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6961 - accuracy: 0.4675
# Epoch 130/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7336 - accuracy: 0.4425
# Epoch 131/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6933 - accuracy: 0.4900
# Epoch 132/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.5000
# Epoch 133/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6942 - accuracy: 0.4925
# Epoch 134/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6940 - accuracy: 0.4650
# Epoch 135/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6936 - accuracy: 0.4500
# Epoch 136/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6973 - accuracy: 0.4775
# Epoch 137/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6951 - accuracy: 0.4675
# Epoch 138/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7008 - accuracy: 0.5000
# Epoch 139/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6975 - accuracy: 0.4600
# Epoch 140/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6984 - accuracy: 0.4900
# Epoch 141/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6968 - accuracy: 0.4875
# Epoch 142/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6946 - accuracy: 0.4750
# Epoch 143/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6979 - accuracy: 0.4875
# Epoch 144/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6955 - accuracy: 0.4875
# Epoch 145/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6943 - accuracy: 0.4275
# Epoch 146/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6993 - accuracy: 0.4800
# Epoch 147/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6945 - accuracy: 0.4875
# Epoch 148/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.7329 - accuracy: 0.4650
# Epoch 149/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6978 - accuracy: 0.4875
# Epoch 150/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6933 - accuracy: 0.4875
# Epoch 151/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.4700
# Epoch 152/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.4625
# Epoch 153/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.4775
# Epoch 154/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6954 - accuracy: 0.4950
# Epoch 155/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6962 - accuracy: 0.4375
# Epoch 156/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7033 - accuracy: 0.4850
# Epoch 157/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6960 - accuracy: 0.4775
# Epoch 158/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6939 - accuracy: 0.4925
# Epoch 159/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6954 - accuracy: 0.4925
# Epoch 160/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6953 - accuracy: 0.4875
# Epoch 161/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7203 - accuracy: 0.4525
# Epoch 162/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.4825
# Epoch 163/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6933 - accuracy: 0.4900
# Epoch 164/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6939 - accuracy: 0.4450
# Epoch 165/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6950 - accuracy: 0.4800
# Epoch 166/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6941 - accuracy: 0.4650
# Epoch 167/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6960 - accuracy: 0.4750
# Epoch 168/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7052 - accuracy: 0.4550
# Epoch 169/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7068 - accuracy: 0.4775
# Epoch 170/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.4700
# Epoch 171/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.4775
# Epoch 172/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.6933 - accuracy: 0.4550
# Epoch 173/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6934 - accuracy: 0.4800
# Epoch 174/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6933 - accuracy: 0.4625
# Epoch 175/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.7593 - accuracy: 0.4725
# Epoch 176/200
# 400/400 [==============================] - 2s 6ms/sample - loss: 0.6935 - accuracy: 0.4425
# Epoch 177/200
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.6934 - accuracy: 0.4625
# Epoch 178/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.6934 - accuracy: 0.4725
# Epoch 179/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4475
# Epoch 180/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6934 - accuracy: 0.4650
# Epoch 181/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.6964 - accuracy: 0.4775
# Epoch 182/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6971 - accuracy: 0.4575
# Epoch 183/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.7070 - accuracy: 0.4350
# Epoch 184/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6948 - accuracy: 0.5000
# Epoch 185/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6938 - accuracy: 0.4550
# Epoch 186/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.7016 - accuracy: 0.4875
# Epoch 187/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6983 - accuracy: 0.4850
# Epoch 188/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6952 - accuracy: 0.4450
# Epoch 189/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6962 - accuracy: 0.4875
# Epoch 190/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6986 - accuracy: 0.4775
# Epoch 191/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6945 - accuracy: 0.4550
# Epoch 192/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.7114 - accuracy: 0.4400
# Epoch 193/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.7705 - accuracy: 0.4900
# Epoch 194/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6934 - accuracy: 0.4675
# Epoch 195/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6934 - accuracy: 0.4725
# Epoch 196/200
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.6934 - accuracy: 0.4800
# Epoch 197/200
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.6934 - accuracy: 0.4850
# Epoch 198/200
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.6934 - accuracy: 0.4850
# Epoch 199/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.6973 - accuracy: 0.4775
# Epoch 200/200
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.6954 - accuracy: 0.4775

# %%
visualize(sample,target, DFFNN_model)
