# %%
import tensorflow as tf
import tensorflow.compat.v1 as tf1
import numpy

# %%
print(tf.version)
x = tf.constant("Hello World")
tf.print("\n",x)
# Out:
# <module 'tensorflow_core._api.v2.version' from '/home/amahadev/.local/lib/python3.7/site-packages/tensorflow_core/_api/v2/version/__init__.py'>
#
#  "Hello World"

# %%
bt = tf.random.normal([10],stddev = 0.1)
b = tf.Variable(bt, name = 'W')
W = tf.Variable(tf.random.normal([784,10],stddev = 0.1),name = 'b')

@tf.function
def forward(x):
    return W*x + b

out = forward(b)
print(out)
print(W.shape,b.shape)
print(W)
# Out:
# tf.Tensor(
# [[-0.0624242  -0.05915125 -0.00089225 ... -0.05973233 -0.01649579
#    0.07733158]
#  [-0.07037286 -0.05431832 -0.00077405 ... -0.05838911 -0.02005544
#    0.07390491]
#  [-0.08739858 -0.05593722 -0.00078802 ... -0.05275579 -0.01951044
#    0.07500045]
#  ...
#  [-0.07710388 -0.07292079 -0.00071746 ... -0.07076129 -0.01695182
#    0.08528963]
#  [-0.07678284 -0.07715739 -0.00074683 ... -0.05796221 -0.01646741
#    0.070484  ]
#  [-0.07481171 -0.06707352 -0.00079383 ... -0.06520489 -0.01465417
#    0.09067149]], shape=(784, 10), dtype=float32)
# (784, 10) (10,)
# <tf.Variable 'b:0' shape=(784, 10) dtype=float32, numpy=
# array([[-0.14793031, -0.07891846,  0.09902023, ...,  0.02112806,
#         -0.07119989, -0.0600918 ],
#        [-0.03943382, -0.1541752 , -0.0465741 , ..., -0.00183434,
#          0.12922692, -0.10174042],
#        [ 0.19296168, -0.12896633, -0.02936633, ..., -0.09813636,
#          0.09854037, -0.08842497],
#        ...,
#        [ 0.05244245,  0.13549565, -0.11627829, ...,  0.20966886,
#         -0.04552304,  0.03663237],
#        [ 0.04806039,  0.20146643, -0.08010548, ..., -0.00913221,
#         -0.07279773, -0.14331906],
#        [ 0.02115509,  0.04444405, -0.02220619, ...,  0.1146818 ,
#         -0.17489293,  0.10204487]], dtype=float32)>

# %%
import tensorflow as tf
from tensorflow import keras

#from tensorflow.keras.models import Sequential

#model = Sequential()

# %%
from tensorflow.keras.layers import Dense, Flatten

model.add(Flatten(input_shape=(28,28)))
model.add(Dense(64,activation='relu'))
model.add(Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                50240
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                704
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                650
# =================================================================
# Total params: 52,244
# Trainable params: 52,244
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss ='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
(x_train, y_train), (x_test,y_test) = tf.keras.datasets.mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
history = model.fit(x_train, y_train, epochs=10)
from matplotlib import pyplot as plt
plt.plot(history.history['loss'],label="loss")
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 5s 91us/sample - loss: 0.0318 - accuracy: 0.9906
# Epoch 2/10
# 60000/60000 [==============================] - 6s 92us/sample - loss: 0.0291 - accuracy: 0.9915
# Epoch 3/10
# 60000/60000 [==============================] - 6s 92us/sample - loss: 0.0268 - accuracy: 0.9919
# Epoch 4/10
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.0239 - accuracy: 0.9927
# Epoch 5/10
# 60000/60000 [==============================] - 5s 91us/sample - loss: 0.0253 - accuracy: 0.9930
# Epoch 6/10
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.0223 - accuracy: 0.9932
# Epoch 7/10
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.0223 - accuracy: 0.9932
# Epoch 8/10
# 60000/60000 [==============================] - 6s 94us/sample - loss: 0.0199 - accuracy: 0.9942
# Epoch 9/10
# 60000/60000 [==============================] - 6s 92us/sample - loss: 0.0189 - accuracy: 0.9941
# Epoch 10/10
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.0203 - accuracy: 0.9941

# %%
model.evaluate(x_test,y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.1383853737529833, 0.9713]

# %%
model.predict(x_test)
# Out:
# array([[7.32082071e-07, 3.46549314e-05, 2.75996808e-06, ...,
#         9.99712527e-01, 2.04838297e-08, 1.01462785e-04],
#        [2.98591840e-09, 3.39688086e-05, 9.99565065e-01, ...,
#         2.42804075e-04, 1.31514871e-05, 2.46663063e-07],
#        [6.36331565e-09, 9.99766052e-01, 8.18328738e-10, ...,
#         2.77540778e-07, 2.20635382e-04, 9.99786625e-13],
#        ...,
#        [3.55774864e-05, 2.09206282e-05, 3.85631074e-06, ...,
#         1.16444617e-05, 4.29032184e-07, 8.12535319e-08],
#        [1.25544909e-06, 4.12679746e-17, 1.27087596e-09, ...,
#         8.70556682e-11, 1.55889222e-06, 2.66553627e-07],
#        [3.53770497e-06, 7.67725258e-11, 1.64493912e-08, ...,
#         5.23486721e-09, 3.22748662e-07, 1.20581534e-09]], dtype=float32)
