# %% [markdown]
# # Deep Learning Course

# %% [markdown]
# ## Assignment 1

# %% [markdown]
# #### Assignment Goals:
#
# * Start with Keras.
# * Implement and apply logistic regression and multi-layer feed-forward neural network classifiers.
# * Understand the differences and trade-offs between linear regression, logistic regression, and multi-layer feed-forward neural network.
#
# In this assignment, you will be asked to install Keras and Jupyter Notebook. Keras is packaged with TensorFlow 2.0 as tensorflow.keras, so you actually need to install Tensorflow 2.0. (TA's environment to run your code is Python 3.7 + Tensorflow 2.4). In addition, you are required to design several models to classify a Toy Dataset (Figure 1).
#
# #### Dataset:
#
# We provide a toy dataset, which has 200 instances and 2 features. See below "Toy Data and Helper Functions" section for toy data generation code.
#
# You do not need to generate separated training dataset and test dataset for this assignment. Both training and prediction will both be on one dataset. Directly use the "sample, target" variables we provide as the dataset for your assignment.
#
# In the following accuracy is defined as the empirical accuracy on the training set, that is, accuracy = {number of correctly predicted instances}/{number of all instances in dataset}).
#
# #### Requirements
#
# 1. Install Keras (Tensorflow 2) and Jupyter Notebook. (10 points)
#
# 2. Implement a [logistic regression](https://towardsdatascience.com/logistic-regression-detailed-overview-46c4da4303bc) to classify the Toy Dataset. (20 points) We have provided a very simple linear regression example, please refer to the example and implement your logistic regression model.
#     * You should determine: what loss function and what optimization algorithm do you plan to use? (4 points)
#     * Try to reach > 72% accuracy. (4 points)
#     * We have provided a visualize() helper function, you can visualize the model's decision boundary using that function. What's more, you are asked to compute and visualize **the equation of the decision boundary** of your trained **logistic regression**. Fill in the 'equation of decision boundary' column in the following table. Then you can modify the visualize() function or implement a new visualization function to draw the linear decision boundary (Hint: should be a straight line aligned with the decision boundary plotted in visualize()). (5 points)
#
#
# 3. Implement a multi-layer linear neural network (>= 2 hidden layers) to classify the Toy Dataset. (20 points) A deep linear neural network is a deep feed-forward neural network without activation functions (See [here](https://www.cs.princeton.edu/courses/archive/fall19/cos597B/lecnotes/linearnetsbyNC.pdf), page 11-13 for detail introduction of linear neural networks).
#     * You should determine: what loss function and what optimization algorithm do you plan to use, what is your network structure? (4 points)
#     * Try to reach > 72% accuracy. (4 points)
#     * Compute and visualize **the equation of the decision boundary** of your trained **linear neural network**. Fill in the 'equation of decision boundary' column in the following table. Then you can modify the visualize() function or implement a new visualization function to draw the linear decision boundary. (5 points)
#
#
# 4. Implement a multi-layer feed-forward neural network (>= 2 hidden layers). (20 points)
#     * You should determine: what loss function and what optimization algorithm do you plan to use? what is your network structure? what activation function do you use? (5 points)
#     * Try to reach 100% accuracy. (5 points)
#
#
# 5. Add L2-regularization to your implemented nonlinear neural network in (4.). Set the coefficient of L2-regularization to be 0.01, 2, 100, respectively. How do different values of coefficient of L2-regularization affect the model (i.e., model parameters, loss value, accuracy, decision boundary)? You can use a table to compare models trained without regularization, with different coefficients of regularization. (20 points)
#     * Please draw your table and analysis in the '**Answers and Analysis**' section.
#
#
# You should:
#
# * Train each of your models to its best accuracy. Then fill in the following table in the '**Answers and Analysis**' section.
#
# * Complete the '**Answers and Analysis**' section.
#
# #### Answers and Analysis
#
# * First, fill in the following table. The '-' indicates a cell that does not need to be filled in.
#
# |  Model | Loss  | Accuracy | Equation of Decision Boundary | NN Structure | Activation Function | Loss Function |
# |---|:---:|:---:|:---: | :---: | :---: | :---: |
# | Linear Regression  |  0.14 |  72.96% | $-1.28x_1+7.62x_2 - 0.07=0$  | -  | -  | Mean Square Error  |
# | Logistic Regression  |   |   |   | -  |  - |   |
# | Linear Neural Network  |   |   |   |   |   |   |
# | Feedforward Neural Network |   |   | -  |   |   |   |
#
#
# * Then, compare and analyze the classification results of your models. In particular, are there any differences between the performance (i.e., accuracy, loss value) of linear regression, logistic regression, linear neural network and deep nonlinear neural network? What do you think is the reason for the difference? (10 points)
#
# * Your table and analysis of (5. Add L2-regularization) here.
#
#
#
# #### Submission Notes:
#
# Please use Jupyter Notebook. The notebook should include the final code, results and your answers. You should submit your Notebook in both .pdf and .ipynb format.
#
#
#
# #### Instructions:
#
# The university policy on academic dishonesty and plagiarism (cheating) will be taken very seriously in this course. Everything submitted should be your own writing or coding. You must not let other students copy your work. Spelling and grammar count.
#
#
# Your assignments will be marked based on correctness, originality (the implementations and ideas are from yourself), clarity and performance.
# Clarity means whether the logic of your code is easy to follow. This includes 1) comments to explain the logic of your code 2) meaningful variable names. Performance includes loss value and accuracy after training.

# %% [markdown]
# ## Your Implementation

# %% [markdown]
# ### Toy Data and Helper Functions

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt

# %%
# helper functions

# helper function for geterating the data
def data_generator(N = 200,D = 2,K = 2):
    """
    N: number of points per class; 
    D: dimensionality; 
    K: number of classes
    """
    np.random.seed(0)
    X = np.zeros((N*K,D))
    y = np.zeros((N*K), dtype='uint8')
    
    for j in range(K):
      ix = range(N*j,N*(j+1))
      r = np.linspace(0.0,1,N) # radius
      t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.3 # theta
      X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
      y[ix] = j
    
    fig = plt.figure()
    plt.title('Figure 1: DataSet')
    plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)
   
    plt.xlim(X.min()-.5, X.max()+.5)
    plt.ylim(X.min()-.5, X.max()+.5)
    
    return X,y


# helper function for visualizing the decision boundaries
def visualize(sample, target, model):
    """
    function for visualizing the classifier boundaries on the TOY dataset.

    sample: Training data features
    target: Target 
    model: the model
    """
    h = 0.02
    x_min, x_max = sample[:, 0].min() - 1, sample[:, 0].max() + 1
    y_min, y_max = sample[:, 1].min() - 1, sample[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    

    Z = model.predict_classes(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    
    fig = plt.figure()
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
    plt.scatter(sample[:, 0], sample[:, 1], c=target, s=40, cmap=plt.cm.Spectral)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    
    return

def visualize_mod(sample, target, model):
    """
    function for visualizing the classifier boundaries on the TOY dataset.

    sample: Training data features
    target: Target 
    model: the model
    """
    h = 0.02
    x_min, x_max = sample[:, 0].min() - 1, sample[:, 0].max() + 1
    y_min, y_max = sample[:, 1].min() - 1, sample[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    
    w1 = model.get_weights()[0][0]
    w2 = model.get_weights()[0][1]
    b = model.get_weights()[1]
    
    x1 = np.arange(x_min,x_max,h)
    x2 = -(w1/w2)*x1 -b/w2
    
    Z = model.predict_classes(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    print(w1[0],"x1 + ",w2[0],"x2",b[0],"= 0")
    fig = plt.figure()
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
    plt.scatter(sample[:, 0], sample[:, 1], c=target, s=40, cmap=plt.cm.Spectral)
    plt.scatter(x1,x2,c='green', s=2)
    
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    
    return


def visualize_dlnn(sample, target, model):
    """
    function for visualizing the classifier boundaries on the TOY dataset.

    sample: Training data features
    target: Target 
    model: the model
    """
    h = 0.02
    x_min, x_max = sample[:, 0].min() - 1, sample[:, 0].max() + 1
    y_min, y_max = sample[:, 1].min() - 1, sample[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    
    wts = DLNN_model.get_weights()
    I = np.ones(shape= (2,2))
    B = np.zeros(shape=(1,2))
    #print(wts)
    index = 0
    count = 1
    for i in range(3):
        I = np.multiply(I,wts[i+index])

        B = np.multiply(B, wts[i+index])
        #print()
        B = np.sum(B,axis = 0)
        B = B + wts[i+count]
        index+=2
        count+=1
    
    x1 = np.arange(x_min,x_max,h)
    
    II = np.sum(I,axis = 1).reshape(2,1)
    w1 = II[0][0]
    w2 = II[1][0]
    b = np.sum(B)
    x2 = -(w1*x1*wts[-2][0])/(w2*wts[-2][1]) -(b+wts[-1])/(w2*wts[-2][1])
    
    ww1 = w1*wts[-2][0]
    ww2 = w2*wts[-2][1]
    bb = b+wts[-1]
    #II = np.multiply(II,wts[-2])
    
    #b = np.sum(B) + wts[-1]

    
    
    
    Z = model.predict_classes(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    #print(ww1,"x1",ww2,"x2",bb,"= 0")
    fig = plt.figure()
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
    plt.scatter(sample[:, 0], sample[:, 1], c=target, s=40, cmap=plt.cm.Spectral)
    plt.scatter(x1,x2,c='green', s=50)
    
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    
    return

# %%
#  TOY DataSet
sample, target = data_generator(N = 200)
# print(target.shape)

# %% [markdown]
# ### Given Example: Linear Regression
#
#
# Note that linear regression is usually used for regression tasks, not classification tasks. However, it can be used for binary classification problems (be labeled 0, 1) with a threshold classifier. That is, when linear regression outputs > 0.5, the prediction is 1; otherwise, the prediction is 0.

# %%
#Define the model
linear_regression = keras.Sequential()

linear_regression.add(keras.layers.Dense(1,"linear"))

linear_regression.compile(optimizer="sgd",loss= keras.losses.MeanSquaredError(), metrics=['accuracy'])

# Train the model
value_epoches = linear_regression.fit(sample, target, epochs=5,batch_size=1)
# Out:
# Train on 400 samples
# Epoch 1/5
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.2848 - accuracy: 0.6000
# Epoch 2/5
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.1631 - accuracy: 0.6300
# Epoch 3/5
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.1477 - accuracy: 0.7025
# Epoch 4/5
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.1444 - accuracy: 0.7275
# Epoch 5/5
# 400/400 [==============================] - 0s 1ms/sample - loss: 0.1431 - accuracy: 0.7425

# %%
visualize(sample,target, linear_regression)

# %% [markdown]
# **Here is an example: the green line is the line of the decision boundary. You should draw the linear decision boundary like this.**

# %% [markdown]
# ![hw1_img1.png](hw1_img1.png)

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# #### Logistic Regression Model & Training Accuracy

# %%
# implement your logistic regression here
logistic_regression = keras.Sequential()

logistic_regression.add(keras.layers.Dense(1,input_shape=(2,),
                                          activation = keras.activations.sigmoid,
                                          bias_initializer=keras.initializers.Constant(0.1)))

logistic_regression.compile(optimizer="sgd",loss= 'binary_crossentropy', metrics=['binary_accuracy'])

# Train the model
value_epoches = logistic_regression.fit(sample, target, epochs=10,batch_size=1,
                                        shuffle=True, verbose = 1, validation_split=0.2)
# Out:
# Train on 320 samples, validate on 80 samples
# Epoch 1/10
# 320/320 [==============================] - 1s 3ms/sample - loss: 0.5851 - binary_accuracy: 0.8375 - val_loss: 1.1976 - val_binary_accuracy: 0.1125
# Epoch 2/10
# 320/320 [==============================] - 1s 2ms/sample - loss: 0.5343 - binary_accuracy: 0.8219 - val_loss: 1.2593 - val_binary_accuracy: 0.1250
# Epoch 3/10
# 320/320 [==============================] - 1s 2ms/sample - loss: 0.5046 - binary_accuracy: 0.8250 - val_loss: 1.2736 - val_binary_accuracy: 0.1625
# Epoch 4/10
# 320/320 [==============================] - 1s 2ms/sample - loss: 0.4827 - binary_accuracy: 0.8250 - val_loss: 1.2714 - val_binary_accuracy: 0.2125
# Epoch 5/10
# 320/320 [==============================] - 1s 2ms/sample - loss: 0.4647 - binary_accuracy: 0.8469 - val_loss: 1.2746 - val_binary_accuracy: 0.2250
# Epoch 6/10
# 320/320 [==============================] - 1s 2ms/sample - loss: 0.4499 - binary_accuracy: 0.8469 - val_loss: 1.2672 - val_binary_accuracy: 0.2375
# Epoch 7/10
# 320/320 [==============================] - 1s 2ms/sample - loss: 0.4371 - binary_accuracy: 0.8531 - val_loss: 1.2597 - val_binary_accuracy: 0.2500
# Epoch 8/10
# 320/320 [==============================] - 1s 2ms/sample - loss: 0.4260 - binary_accuracy: 0.8625 - val_loss: 1.2587 - val_binary_accuracy: 0.2750
# Epoch 9/10
# 320/320 [==============================] - 1s 2ms/sample - loss: 0.4165 - binary_accuracy: 0.8594 - val_loss: 1.2553 - val_binary_accuracy: 0.3000
# Epoch 10/10
# 320/320 [==============================] - 1s 2ms/sample - loss: 0.4081 - binary_accuracy: 0.8625 - val_loss: 1.2668 - val_binary_accuracy: 0.3500

# %% [markdown]
# #### Logistic Regression Model Visualization

# %%
print(logistic_regression.summary())
tf.keras.utils.plot_model(logistic_regression,show_shapes=True,
                          show_layer_names=True,
                          rankdir="TB",expand_nested=True,dpi=96,)
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# #### Visualization: Decision Boundary and Equation

# %%
visualize_mod(sample,target, logistic_regression)
# Out:
# -2.2350557 x1 +  2.2906082 x2 -0.40496278 = 0

# %% [markdown]
# ### Deep Linear Neural Network

# %% [markdown]
# ####  Deep linear NN Model & Training Accuracy

# %%
# # implement your nonlinear feed forward neural network here
DLNN_model = keras.Sequential()

DLNN_model.add(keras.layers.Dense(2,input_shape=(2,),
                                          activation = tf.keras.activations.linear,))
DLNN_model.add(keras.layers.Dense(2,input_shape=(2,),
                                          activation = tf.keras.activations.linear,))
DLNN_model.add(keras.layers.Dense(2,input_shape=(2,),
                                          activation = tf.keras.activations.linear,))

DLNN_model.add(keras.layers.Dense(1,input_shape=(2,),
                                          activation = tf.keras.activations.sigmoid,))

DLNN_model.compile(optimizer="sgd",loss= 'binary_crossentropy', metrics=['binary_accuracy'])

# Train the model
value_epoches = DLNN_model.fit(sample, target, epochs=5,batch_size=1,
                                        shuffle=True, verbose = 1, validation_split=0.2)
# Out:
# Train on 320 samples, validate on 80 samples
# Epoch 1/5
# 320/320 [==============================] - 1s 3ms/sample - loss: 0.6377 - binary_accuracy: 0.6250 - val_loss: 1.0275 - val_binary_accuracy: 0.2500
# Epoch 2/5
# 320/320 [==============================] - 1s 3ms/sample - loss: 0.4057 - binary_accuracy: 0.8406 - val_loss: 1.5358 - val_binary_accuracy: 0.4250
# Epoch 3/5
# 320/320 [==============================] - 1s 3ms/sample - loss: 0.3153 - binary_accuracy: 0.8406 - val_loss: 2.3035 - val_binary_accuracy: 0.3875
# Epoch 4/5
# 320/320 [==============================] - 1s 3ms/sample - loss: 0.3025 - binary_accuracy: 0.8438 - val_loss: 2.0965 - val_binary_accuracy: 0.4750
# Epoch 5/5
# 320/320 [==============================] - 1s 2ms/sample - loss: 0.2866 - binary_accuracy: 0.8719 - val_loss: 2.3091 - val_binary_accuracy: 0.4750

# %% [markdown]
# #### DLL Model Visualization

# %%
print(DLNN_model.summary())
tf.keras.utils.plot_model(DLNN_model,show_shapes=True,
                          show_layer_names=True,
                          rankdir="TB",expand_nested=True,dpi=96,)
# Out:
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_76 (Dense)             (None, 2)                 6
# _________________________________________________________________
# dense_77 (Dense)             (None, 2)                 6
# _________________________________________________________________
# dense_78 (Dense)             (None, 2)                 6
# _________________________________________________________________
# dense_79 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
visualize_dlnn(sample,target, DLNN_model)
# Out:
# [[ 0. -0.]
#  [-0.  0.]]
# [0.00011333 0.00156426]
# [[ 0.03714548  0.0475162 ]
#  [-0.0101329  -0.01296192]]
# [-0.07692084] x1 [0.00471165] x2 [0.03124805] = 0

# %% [markdown]
# ### Deep Neural Network

# %%
DFFNN_model = keras.Sequential()

DFFNN_model.add(keras.layers.Dense(96,input_shape=(2,),
                                          activation = tf.keras.activations.tanh,))
DFFNN_model.add(keras.layers.Dense(200,input_shape=(96,),
                                          activation = tf.keras.activations.tanh,))
DFFNN_model.add(keras.layers.Dense(96,input_shape=(200,),
                                          activation = tf.keras.activations.relu,))
DFFNN_model.add(keras.layers.Dense(24,input_shape=(48,),
                                          activation = tf.keras.activations.relu,))
DFFNN_model.add(keras.layers.Dense(2,input_shape=(24,),
                                          activation = tf.keras.activations.relu,))

DFFNN_model.add(keras.layers.Dense(1,input_shape=(2,),
                                          activation = tf.keras.activations.sigmoid,))

DFFNN_model.compile(optimizer="adam",loss= 'binary_crossentropy', metrics=['accuracy'])

# Train the model
value_epoches = DFFNN_model.fit(sample, target, epochs=500,batch_size=1,
                                        shuffle=True, verbose = 1, validation_split=0.0)
# Out:
# Train on 400 samples
# Epoch 1/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.5744 - accuracy: 0.6900
# Epoch 2/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.5348 - accuracy: 0.7325
# Epoch 3/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.5284 - accuracy: 0.7350
# Epoch 4/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.5212 - accuracy: 0.7200
# Epoch 5/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.5058 - accuracy: 0.7325
# Epoch 6/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.5150 - accuracy: 0.7275
# Epoch 7/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.5184 - accuracy: 0.7150
# Epoch 8/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.5324 - accuracy: 0.7225
# Epoch 9/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.5097 - accuracy: 0.7250
# Epoch 10/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.4883 - accuracy: 0.7500
# Epoch 11/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.4996 - accuracy: 0.7600
# Epoch 12/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.4600 - accuracy: 0.7725
# Epoch 13/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.4385 - accuracy: 0.8150
# Epoch 14/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.3396 - accuracy: 0.8975
# Epoch 15/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.2503 - accuracy: 0.9550
# Epoch 16/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.2202 - accuracy: 0.9675
# Epoch 17/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.1871 - accuracy: 0.9675
# Epoch 18/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.1807 - accuracy: 0.9625
# Epoch 19/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.1453 - accuracy: 0.9800
# Epoch 20/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.1373 - accuracy: 0.9775
# Epoch 21/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.2148 - accuracy: 0.9350
# Epoch 22/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.1850 - accuracy: 0.9475
# Epoch 23/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.1192 - accuracy: 0.9825
# Epoch 24/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0991 - accuracy: 0.9850
# Epoch 25/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0952 - accuracy: 0.9850
# Epoch 26/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0641 - accuracy: 0.9975
# Epoch 27/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0789 - accuracy: 0.9900
# Epoch 28/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.1526 - accuracy: 0.9600
# Epoch 29/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0697 - accuracy: 0.9825
# Epoch 30/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0695 - accuracy: 0.9825
# Epoch 31/500
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0591 - accuracy: 0.9875
# Epoch 32/500
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0589 - accuracy: 0.9875
# Epoch 33/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0653 - accuracy: 0.9850
# Epoch 34/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0728 - accuracy: 0.9875
# Epoch 35/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0472 - accuracy: 0.9925
# Epoch 36/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0443 - accuracy: 0.9900
# Epoch 37/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0479 - accuracy: 0.9925
# Epoch 38/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.1474 - accuracy: 0.9525
# Epoch 39/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0379 - accuracy: 0.9925
# Epoch 40/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0442 - accuracy: 0.9900
# Epoch 41/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0331 - accuracy: 0.9950
# Epoch 42/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0369 - accuracy: 0.9950
# Epoch 43/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0534 - accuracy: 0.9900
# Epoch 44/500
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0340 - accuracy: 0.9925
# Epoch 45/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0335 - accuracy: 0.9950
# Epoch 46/500
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0312 - accuracy: 0.9950
# Epoch 47/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0395 - accuracy: 0.9875
# Epoch 48/500
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0365 - accuracy: 0.9900
# Epoch 49/500
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.1132 - accuracy: 0.9675
# Epoch 50/500
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0333 - accuracy: 0.9950
# Epoch 51/500
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0362 - accuracy: 0.9900
# Epoch 52/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.1603 - accuracy: 0.9775
# Epoch 53/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0224 - accuracy: 0.9925
# Epoch 54/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0260 - accuracy: 0.9925
# Epoch 55/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0331 - accuracy: 0.9900
# Epoch 56/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0233 - accuracy: 0.9925
# Epoch 57/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0178 - accuracy: 0.9950
# Epoch 58/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0272 - accuracy: 0.9950
# Epoch 59/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0190 - accuracy: 0.9950
# Epoch 60/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0348 - accuracy: 0.9900
# Epoch 61/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0251 - accuracy: 0.9975
# Epoch 62/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0486 - accuracy: 0.9875
# Epoch 63/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0148 - accuracy: 0.9975
# Epoch 64/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0489 - accuracy: 0.9825
# Epoch 65/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.1055 - accuracy: 0.9725
# Epoch 66/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0738 - accuracy: 0.9800
# Epoch 67/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0275 - accuracy: 0.9900
# Epoch 68/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0147 - accuracy: 0.9975
# Epoch 69/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0199 - accuracy: 0.9950
# Epoch 70/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0584 - accuracy: 0.9850
# Epoch 71/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0159 - accuracy: 0.9950
# Epoch 72/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0381 - accuracy: 0.9850
# Epoch 73/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0182 - accuracy: 0.9950
# Epoch 74/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0196 - accuracy: 0.9925
# Epoch 75/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0161 - accuracy: 0.9975
# Epoch 76/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0128 - accuracy: 0.9975
# Epoch 77/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0392 - accuracy: 0.9875
# Epoch 78/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0201 - accuracy: 0.9925
# Epoch 79/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1342 - accuracy: 0.9650
# Epoch 80/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0191 - accuracy: 0.9950
# Epoch 81/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0190 - accuracy: 0.9925
# Epoch 82/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0180 - accuracy: 0.9950
# Epoch 83/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0109 - accuracy: 0.9975
# Epoch 84/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0262 - accuracy: 0.9925
# Epoch 85/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0167 - accuracy: 0.9925
# Epoch 86/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0189 - accuracy: 0.9925
# Epoch 87/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0227 - accuracy: 0.9925
# Epoch 88/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0181 - accuracy: 0.9950
# Epoch 89/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0107 - accuracy: 1.0000
# Epoch 90/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0415 - accuracy: 0.9850
# Epoch 91/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0161 - accuracy: 0.9975
# Epoch 92/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0151 - accuracy: 0.9950
# Epoch 93/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0166 - accuracy: 0.9950
# Epoch 94/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0232 - accuracy: 0.9925
# Epoch 95/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0151 - accuracy: 0.9950
# Epoch 96/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0192 - accuracy: 0.9950
# Epoch 97/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1437 - accuracy: 0.9700
# Epoch 98/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1048 - accuracy: 0.9800
# Epoch 99/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0201 - accuracy: 0.9875
# Epoch 100/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0158 - accuracy: 0.9950
# Epoch 101/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0138 - accuracy: 0.9950
# Epoch 102/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0242 - accuracy: 0.9925
# Epoch 103/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0136 - accuracy: 0.9975
# Epoch 104/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0174 - accuracy: 0.9925
# Epoch 105/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0161 - accuracy: 0.9950
# Epoch 106/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0128 - accuracy: 0.9950
# Epoch 107/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0129 - accuracy: 0.9950
# Epoch 108/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0070 - accuracy: 0.9975
# Epoch 109/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0250 - accuracy: 0.9900
# Epoch 110/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0149 - accuracy: 0.9950
# Epoch 111/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0171 - accuracy: 0.9925
# Epoch 112/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0197 - accuracy: 0.9925
# Epoch 113/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.2441 - accuracy: 0.9600
# Epoch 114/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1120 - accuracy: 0.9750
# Epoch 115/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0195 - accuracy: 0.9950
# Epoch 116/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0139 - accuracy: 0.9925
# Epoch 117/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0182 - accuracy: 0.9900
# Epoch 118/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0130 - accuracy: 0.9950
# Epoch 119/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0122 - accuracy: 0.9950
# Epoch 120/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0267 - accuracy: 0.9900
# Epoch 121/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0135 - accuracy: 0.9925
# Epoch 122/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0199 - accuracy: 0.9925
# Epoch 123/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0160 - accuracy: 0.9925
# Epoch 124/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0201 - accuracy: 0.9900
# Epoch 125/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0331 - accuracy: 0.9900
# Epoch 126/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1502 - accuracy: 0.9575
# Epoch 127/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0120 - accuracy: 0.9950
# Epoch 128/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0130 - accuracy: 0.9950
# Epoch 129/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0147 - accuracy: 0.9925
# Epoch 130/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0135 - accuracy: 0.9925
# Epoch 131/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0182 - accuracy: 0.9975
# Epoch 132/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0143 - accuracy: 0.9950
# Epoch 133/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0117 - accuracy: 0.9975
# Epoch 134/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0097 - accuracy: 0.9975
# Epoch 135/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0181 - accuracy: 0.9925
# Epoch 136/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0112 - accuracy: 0.9950
# Epoch 137/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0196 - accuracy: 0.9950
# Epoch 138/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0151 - accuracy: 0.9950
# Epoch 139/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0169 - accuracy: 0.9950
# Epoch 140/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0132 - accuracy: 0.9925
# Epoch 141/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0104 - accuracy: 0.9975
# Epoch 142/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0211 - accuracy: 0.9950
# Epoch 143/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0166 - accuracy: 0.9900
# Epoch 144/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0067 - accuracy: 1.0000
# Epoch 145/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0572 - accuracy: 0.9875
# Epoch 146/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0380 - accuracy: 0.9900
# Epoch 147/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0165 - accuracy: 0.9925
# Epoch 148/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0132 - accuracy: 0.9950
# Epoch 149/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0285 - accuracy: 0.9950
# Epoch 150/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0110 - accuracy: 0.9950
# Epoch 151/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0140 - accuracy: 0.9925
# Epoch 152/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0139 - accuracy: 0.9950
# Epoch 153/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0140 - accuracy: 0.9975
# Epoch 154/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0079 - accuracy: 0.9975
# Epoch 155/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0137 - accuracy: 0.9925
# Epoch 156/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0133 - accuracy: 0.9950
# Epoch 157/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0135 - accuracy: 0.9925
# Epoch 158/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0254 - accuracy: 0.9900
# Epoch 159/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.4307 - accuracy: 0.9325
# Epoch 160/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0501 - accuracy: 0.9800
# Epoch 161/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0160 - accuracy: 0.9925
# Epoch 162/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0153 - accuracy: 0.9950
# Epoch 163/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0119 - accuracy: 0.9925
# Epoch 164/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0094 - accuracy: 0.9950
# Epoch 165/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0182 - accuracy: 0.9925
# Epoch 166/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0126 - accuracy: 0.9950
# Epoch 167/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0117 - accuracy: 0.9950
# Epoch 168/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0185 - accuracy: 0.9925
# Epoch 169/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0120 - accuracy: 0.9950
# Epoch 170/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0120 - accuracy: 0.9950
# Epoch 171/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0124 - accuracy: 0.9950
# Epoch 172/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0126 - accuracy: 0.9925
# Epoch 173/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0207 - accuracy: 0.9925
# Epoch 174/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0140 - accuracy: 0.9900
# Epoch 175/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0149 - accuracy: 0.9950
# Epoch 176/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0107 - accuracy: 0.9950
# Epoch 177/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0102 - accuracy: 0.9950
# Epoch 178/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0283 - accuracy: 0.9950
# Epoch 179/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0834 - accuracy: 0.9750
# Epoch 180/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0333 - accuracy: 0.9925
# Epoch 181/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0171 - accuracy: 0.9925
# Epoch 182/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0133 - accuracy: 0.9950
# Epoch 183/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0084 - accuracy: 0.9950
# Epoch 184/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0187 - accuracy: 0.9950
# Epoch 185/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0122 - accuracy: 0.9925
# Epoch 186/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0123 - accuracy: 0.9975
# Epoch 187/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1088 - accuracy: 0.9800
# Epoch 188/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0223 - accuracy: 0.9900
# Epoch 189/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0106 - accuracy: 0.9950
# Epoch 190/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0173 - accuracy: 0.9925
# Epoch 191/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0103 - accuracy: 0.9925
# Epoch 192/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0103 - accuracy: 0.9950
# Epoch 193/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0111 - accuracy: 0.9975
# Epoch 194/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0061 - accuracy: 0.9975
# Epoch 195/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0240 - accuracy: 0.9950
# Epoch 196/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0118 - accuracy: 0.9950
# Epoch 197/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0155 - accuracy: 0.9950
# Epoch 198/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0119 - accuracy: 0.9925
# Epoch 199/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0118 - accuracy: 0.9975
# Epoch 200/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0112 - accuracy: 0.9950
# Epoch 201/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0164 - accuracy: 0.9975
# Epoch 202/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0154 - accuracy: 0.9950
# Epoch 203/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0134 - accuracy: 0.9950
# Epoch 204/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0108 - accuracy: 0.9975
# Epoch 205/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0122 - accuracy: 0.9925
# Epoch 206/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0097 - accuracy: 0.9975
# Epoch 207/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0187 - accuracy: 0.9950
# Epoch 208/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0106 - accuracy: 0.9975
# Epoch 209/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0166 - accuracy: 0.9950
# Epoch 210/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0145 - accuracy: 0.9925
# Epoch 211/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0083 - accuracy: 0.9975
# Epoch 212/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0116 - accuracy: 0.9925
# Epoch 213/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1468 - accuracy: 0.9750
# Epoch 214/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1819 - accuracy: 0.9750
# Epoch 215/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0081 - accuracy: 0.9975
# Epoch 216/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0106 - accuracy: 0.9950
# Epoch 217/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0128 - accuracy: 0.9975
# Epoch 218/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0105 - accuracy: 0.9950
# Epoch 219/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0166 - accuracy: 0.9950
# Epoch 220/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0086 - accuracy: 0.9975
# Epoch 221/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0139 - accuracy: 0.9950
# Epoch 222/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0125 - accuracy: 0.9900
# Epoch 223/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0125 - accuracy: 0.9950
# Epoch 224/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0118 - accuracy: 0.9975
# Epoch 225/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0102 - accuracy: 0.9925
# Epoch 226/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0081 - accuracy: 0.9975
# Epoch 227/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0044 - accuracy: 1.0000
# Epoch 228/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.1312 - accuracy: 0.9725
# Epoch 229/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0300 - accuracy: 0.9925
# Epoch 230/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0344 - accuracy: 0.9925
# Epoch 231/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0225 - accuracy: 0.9950
# Epoch 232/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0216 - accuracy: 0.9950
# Epoch 233/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0279 - accuracy: 0.9950
# Epoch 234/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0278 - accuracy: 0.9900
# Epoch 235/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0250 - accuracy: 0.9925
# Epoch 236/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0240 - accuracy: 0.9925
# Epoch 237/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0231 - accuracy: 0.9950
# Epoch 238/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0260 - accuracy: 0.9925
# Epoch 239/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0281 - accuracy: 0.9925
# Epoch 240/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0257 - accuracy: 0.9925
# Epoch 241/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0246 - accuracy: 0.9900
# Epoch 242/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0209 - accuracy: 0.9950
# Epoch 243/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0402 - accuracy: 0.9900
# Epoch 244/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0202 - accuracy: 0.9925
# Epoch 245/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0992 - accuracy: 0.9825
# Epoch 246/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0090 - accuracy: 0.9975
# Epoch 247/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0129 - accuracy: 0.9950
# Epoch 248/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0161 - accuracy: 0.9950
# Epoch 249/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0098 - accuracy: 0.9950
# Epoch 250/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0112 - accuracy: 0.9975
# Epoch 251/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0128 - accuracy: 0.9950
# Epoch 252/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0107 - accuracy: 0.9950
# Epoch 253/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0147 - accuracy: 0.9925
# Epoch 254/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0114 - accuracy: 0.9925
# Epoch 255/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0113 - accuracy: 0.9975
# Epoch 256/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0113 - accuracy: 0.9925
# Epoch 257/500
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0104 - accuracy: 0.9925
# Epoch 258/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0253 - accuracy: 0.9925
# Epoch 259/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0147 - accuracy: 0.9950
# Epoch 260/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0096 - accuracy: 0.9975
# Epoch 261/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0080 - accuracy: 0.9950
# Epoch 262/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0093 - accuracy: 0.9950
# Epoch 263/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0071 - accuracy: 0.9975
# Epoch 264/500
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0227 - accuracy: 0.9925
# Epoch 265/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0114 - accuracy: 0.9950
# Epoch 266/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0064 - accuracy: 0.9975
# Epoch 267/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0159 - accuracy: 0.9925
# Epoch 268/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0131 - accuracy: 0.9950
# Epoch 269/500
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0088 - accuracy: 0.9950
# Epoch 270/500
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0166 - accuracy: 0.9975
# Epoch 271/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.1518 - accuracy: 0.9675
# Epoch 272/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0325 - accuracy: 0.9900
# Epoch 273/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0116 - accuracy: 0.9950
# Epoch 274/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0069 - accuracy: 0.9975
# Epoch 275/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0092 - accuracy: 0.9950
# Epoch 276/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0051 - accuracy: 1.0000
# Epoch 277/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0143 - accuracy: 0.9950
# Epoch 278/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0170 - accuracy: 0.9975
# Epoch 279/500
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0081 - accuracy: 0.9950
# Epoch 280/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0105 - accuracy: 0.9950
# Epoch 281/500
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0079 - accuracy: 0.9950
# Epoch 282/500
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0112 - accuracy: 0.9950
# Epoch 283/500
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0058 - accuracy: 0.9975
# Epoch 284/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0178 - accuracy: 0.9950
# Epoch 285/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0090 - accuracy: 0.9950
# Epoch 286/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0042 - accuracy: 0.9975
# Epoch 287/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0137 - accuracy: 0.9950
# Epoch 288/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0143 - accuracy: 0.9950
# Epoch 289/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0069 - accuracy: 0.9975
# Epoch 290/500
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0093 - accuracy: 0.9975
# Epoch 291/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0056 - accuracy: 0.9975
# Epoch 292/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0297 - accuracy: 0.9925
# Epoch 293/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0110 - accuracy: 0.9975
# Epoch 294/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0078 - accuracy: 0.9975
# Epoch 295/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0083 - accuracy: 0.9950
# Epoch 296/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0090 - accuracy: 0.9950
# Epoch 297/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0088 - accuracy: 0.9950
# Epoch 298/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0089 - accuracy: 0.9950
# Epoch 299/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.1432 - accuracy: 0.9725
# Epoch 300/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0514 - accuracy: 0.9875
# Epoch 301/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0071 - accuracy: 0.9975
# Epoch 302/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0098 - accuracy: 0.9950
# Epoch 303/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0074 - accuracy: 0.9975
# Epoch 304/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0122 - accuracy: 0.9950
# Epoch 305/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0115 - accuracy: 0.9950
# Epoch 306/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0087 - accuracy: 0.9925
# Epoch 307/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0085 - accuracy: 0.9950
# Epoch 308/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0080 - accuracy: 0.9950
# Epoch 309/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0091 - accuracy: 0.9950
# Epoch 310/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0200 - accuracy: 0.9950
# Epoch 311/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0177 - accuracy: 0.9950
# Epoch 312/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0083 - accuracy: 0.9975
# Epoch 313/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0092 - accuracy: 0.9975
# Epoch 314/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0079 - accuracy: 0.9950
# Epoch 315/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0102 - accuracy: 0.9925
# Epoch 316/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0073 - accuracy: 0.9975
# Epoch 317/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0084 - accuracy: 0.9925
# Epoch 318/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0260 - accuracy: 0.9950
# Epoch 319/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0074 - accuracy: 0.9950
# Epoch 320/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0149 - accuracy: 0.9950
# Epoch 321/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0076 - accuracy: 0.9950
# Epoch 322/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0074 - accuracy: 0.9975
# Epoch 323/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0178 - accuracy: 0.9975
# Epoch 324/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0082 - accuracy: 0.9950
# Epoch 325/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0071 - accuracy: 0.9975
# Epoch 326/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.1065 - accuracy: 0.9750
# Epoch 327/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0281 - accuracy: 0.9925
# Epoch 328/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0130 - accuracy: 0.9950
# Epoch 329/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0084 - accuracy: 0.9975
# Epoch 330/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0106 - accuracy: 0.9950
# Epoch 331/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0074 - accuracy: 0.9950
# Epoch 332/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0056 - accuracy: 0.9975
# Epoch 333/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0171 - accuracy: 0.9900
# Epoch 334/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0073 - accuracy: 0.9975
# Epoch 335/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0072 - accuracy: 0.9975
# Epoch 336/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0079 - accuracy: 0.9950
# Epoch 337/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0123 - accuracy: 0.9950
# Epoch 338/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0119 - accuracy: 0.9950
# Epoch 339/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0074 - accuracy: 0.9950
# Epoch 340/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0085 - accuracy: 0.9950
# Epoch 341/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0077 - accuracy: 0.9975
# Epoch 342/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0091 - accuracy: 0.9975
# Epoch 343/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0076 - accuracy: 0.9975
# Epoch 344/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0074 - accuracy: 0.9975
# Epoch 345/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0190 - accuracy: 0.9900
# Epoch 346/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0155 - accuracy: 0.9925
# Epoch 347/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0133 - accuracy: 0.9925
# Epoch 348/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0093 - accuracy: 0.9950
# Epoch 349/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0061 - accuracy: 0.9975
# Epoch 350/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0146 - accuracy: 0.9925
# Epoch 351/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0083 - accuracy: 0.9950
# Epoch 352/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0066 - accuracy: 0.9975
# Epoch 353/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0212 - accuracy: 0.9925
# Epoch 354/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0700 - accuracy: 0.9875
# Epoch 355/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0231 - accuracy: 0.9950
# Epoch 356/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0230 - accuracy: 0.9950
# Epoch 357/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0256 - accuracy: 0.9950
# Epoch 358/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0241 - accuracy: 0.9925
# Epoch 359/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0220 - accuracy: 0.9950
# Epoch 360/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0369 - accuracy: 0.9900
# Epoch 361/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0075 - accuracy: 0.9975
# Epoch 362/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0078 - accuracy: 0.9975
# Epoch 363/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0129 - accuracy: 0.9950
# Epoch 364/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0067 - accuracy: 0.9950
# Epoch 365/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0098 - accuracy: 0.9925
# Epoch 366/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0074 - accuracy: 0.9950
# Epoch 367/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0072 - accuracy: 0.9925
# Epoch 368/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0190 - accuracy: 0.9950
# Epoch 369/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0079 - accuracy: 0.9950
# Epoch 370/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0072 - accuracy: 0.9975
# Epoch 371/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0232 - accuracy: 0.9950
# Epoch 372/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0077 - accuracy: 0.9975
# Epoch 373/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0067 - accuracy: 0.9950
# Epoch 374/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0108 - accuracy: 0.9950
# Epoch 375/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0429 - accuracy: 0.9900
# Epoch 376/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0071 - accuracy: 0.9950
# Epoch 377/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0072 - accuracy: 0.9975
# Epoch 378/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0075 - accuracy: 0.9950
# Epoch 379/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0098 - accuracy: 0.9950
# Epoch 380/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0095 - accuracy: 0.9975
# Epoch 381/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0061 - accuracy: 0.9975
# Epoch 382/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0033 - accuracy: 1.0000
# Epoch 383/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0168 - accuracy: 0.9950
# Epoch 384/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0072 - accuracy: 1.0000
# Epoch 385/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0207 - accuracy: 0.9950
# Epoch 386/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0067 - accuracy: 0.9975
# Epoch 387/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0056 - accuracy: 0.9975
# Epoch 388/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0088 - accuracy: 0.9975
# Epoch 389/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0182 - accuracy: 0.9975
# Epoch 390/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0077 - accuracy: 0.9950
# Epoch 391/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0065 - accuracy: 0.9975
# Epoch 392/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0067 - accuracy: 0.9950
# Epoch 393/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0094 - accuracy: 0.9975
# Epoch 394/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0118 - accuracy: 0.9950
# Epoch 395/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0092 - accuracy: 0.9950
# Epoch 396/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0099 - accuracy: 0.9950
# Epoch 397/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0339 - accuracy: 0.9875
# Epoch 398/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0062 - accuracy: 0.9975
# Epoch 399/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0098 - accuracy: 0.9925
# Epoch 400/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0138 - accuracy: 0.9950
# Epoch 401/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0075 - accuracy: 0.9975
# Epoch 402/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0071 - accuracy: 0.9950
# Epoch 403/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0068 - accuracy: 0.9975
# Epoch 404/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0490 - accuracy: 0.9850
# Epoch 405/500
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0077 - accuracy: 0.9950
# Epoch 406/500
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0059 - accuracy: 0.9975
# Epoch 407/500
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0189 - accuracy: 0.9975
# Epoch 408/500
# 400/400 [==============================] - 1s 1ms/sample - loss: 0.0067 - accuracy: 0.9950
# Epoch 409/500
# 400/400 [==============================] - 1s 2ms/sample - loss: 0.0140 - accuracy: 0.9950
# Epoch 410/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0067 - accuracy: 0.9950
# Epoch 411/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0068 - accuracy: 0.9975
# Epoch 412/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0113 - accuracy: 0.9925
# Epoch 413/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0073 - accuracy: 0.9950
# Epoch 414/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0058 - accuracy: 0.9950
# Epoch 415/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0104 - accuracy: 0.9975
# Epoch 416/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0128 - accuracy: 0.9950
# Epoch 417/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0059 - accuracy: 0.9950
# Epoch 418/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0164 - accuracy: 0.9950
# Epoch 419/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0115 - accuracy: 0.9975
# Epoch 420/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0114 - accuracy: 0.9975
# Epoch 421/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0104 - accuracy: 0.9950
# Epoch 422/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0072 - accuracy: 0.9975
# Epoch 423/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0059 - accuracy: 0.9975
# Epoch 424/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0083 - accuracy: 0.9950
# Epoch 425/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0672 - accuracy: 0.9875
# Epoch 426/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0640 - accuracy: 0.9800
# Epoch 427/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0085 - accuracy: 0.9950
# Epoch 428/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0064 - accuracy: 0.9950
# Epoch 429/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0080 - accuracy: 0.9950
# Epoch 430/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0049 - accuracy: 0.9975
# Epoch 431/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0080 - accuracy: 0.9950
# Epoch 432/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0078 - accuracy: 0.9950
# Epoch 433/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0192 - accuracy: 0.9925
# Epoch 434/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0056 - accuracy: 0.9950
# Epoch 435/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0064 - accuracy: 0.9975
# Epoch 436/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0066 - accuracy: 0.9950
# Epoch 437/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0071 - accuracy: 0.9950
# Epoch 438/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0066 - accuracy: 0.9975
# Epoch 439/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0043 - accuracy: 1.0000
# Epoch 440/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0119 - accuracy: 0.9950
# Epoch 441/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0092 - accuracy: 0.9925
# Epoch 442/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0057 - accuracy: 0.9950
# Epoch 443/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0064 - accuracy: 0.9950
# Epoch 444/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0061 - accuracy: 0.9975
# Epoch 445/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0061 - accuracy: 0.9975
# Epoch 446/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0071 - accuracy: 0.9975
# Epoch 447/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0198 - accuracy: 0.9950
# Epoch 448/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0178 - accuracy: 0.9975
# Epoch 449/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0481 - accuracy: 0.9850
# Epoch 450/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0494 - accuracy: 0.9850
# Epoch 451/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0207 - accuracy: 0.9900
# Epoch 452/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0072 - accuracy: 0.9975
# Epoch 453/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0059 - accuracy: 0.9975
# Epoch 454/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0068 - accuracy: 0.9975
# Epoch 455/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0066 - accuracy: 0.9950
# Epoch 456/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0065 - accuracy: 0.9950
# Epoch 457/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0076 - accuracy: 0.9950
# Epoch 458/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0063 - accuracy: 0.9950
# Epoch 459/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0059 - accuracy: 0.9975
# Epoch 460/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0067 - accuracy: 0.9975
# Epoch 461/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0106 - accuracy: 0.9975
# Epoch 462/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0073 - accuracy: 0.9975
# Epoch 463/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0060 - accuracy: 0.9975
# Epoch 464/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0098 - accuracy: 0.9950
# Epoch 465/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0143 - accuracy: 0.9975
# Epoch 466/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0087 - accuracy: 0.9950
# Epoch 467/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0066 - accuracy: 0.9950
# Epoch 468/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0062 - accuracy: 0.9975
# Epoch 469/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0064 - accuracy: 0.9950
# Epoch 470/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0053 - accuracy: 0.9975
# Epoch 471/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0061 - accuracy: 0.9975
# Epoch 472/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0066 - accuracy: 0.9950
# Epoch 473/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0346 - accuracy: 0.9900
# Epoch 474/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0142 - accuracy: 0.9950
# Epoch 475/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0075 - accuracy: 0.9975
# Epoch 476/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0156 - accuracy: 0.9925
# Epoch 477/500
# 400/400 [==============================] - 2s 5ms/sample - loss: 0.0128 - accuracy: 0.9950
# Epoch 478/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0073 - accuracy: 0.9950
# Epoch 479/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0062 - accuracy: 0.9950
# Epoch 480/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0065 - accuracy: 0.9950
# Epoch 481/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0052 - accuracy: 0.9975
# Epoch 482/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0067 - accuracy: 0.9950
# Epoch 483/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0130 - accuracy: 0.9975
# Epoch 484/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0085 - accuracy: 0.9950
# Epoch 485/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0074 - accuracy: 0.9950
# Epoch 486/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0063 - accuracy: 0.9950
# Epoch 487/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0089 - accuracy: 0.9950
# Epoch 488/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0065 - accuracy: 0.9950
# Epoch 489/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0062 - accuracy: 0.9975
# Epoch 490/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0058 - accuracy: 0.9975
# Epoch 491/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0069 - accuracy: 0.9950
# Epoch 492/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0067 - accuracy: 0.9975
# Epoch 493/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0058 - accuracy: 0.9975
# Epoch 494/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0668 - accuracy: 0.9950
# Epoch 495/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0146 - accuracy: 0.9925
# Epoch 496/500
# 400/400 [==============================] - 1s 4ms/sample - loss: 0.0132 - accuracy: 0.9975
# Epoch 497/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0070 - accuracy: 0.9975
# Epoch 498/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0067 - accuracy: 0.9975
# Epoch 499/500
# 400/400 [==============================] - 1s 3ms/sample - loss: 0.0130 - accuracy: 0.9975
# Epoch 500/500
# 400/400 [==============================] - 2s 4ms/sample - loss: 0.0097 - accuracy: 0.9950

# %%
visualize(sample,target, DFFNN_model)

# %%
# implement your nonlinear feed forward neural network here

# %% [markdown]
# ### Deep Neural Network with L2-regularization
#
# $\lambda = 0.01, 2, 100$
